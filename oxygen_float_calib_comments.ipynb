# %%
import numpy as np
import pandas as pd
import xarray as xr
import glob, os
import matplotlib.pyplot as plt
import time
import scipy.stats as stats
import matplotlib.dates as mdates
import re
import csv

# %%
# read in a user-created text file to point to local directories to avoid having to change this every time 
# we update code
lines=[]
with open('path_file.txt') as f:
    lines = f.readlines()
    
count = 0
for line in lines:
    count += 1
    index = line.find("=")
    #print(f'line {count}: {line}')
    #print(index)
    #print(line[0:index])
    line = line.rstrip()
    if line[0:index].find("argo")>=0:
        argo_path=line[index+1:]
    elif line[0:index].find("liar")>=0:
        liar_dir=line[index+1:]
    elif line[0:index].find("matlab")>=0:
        matlab_dir=line[index+1:]
        
# Set the paths
output_dir = 'output/'
data_dir = 'data/'

# %%
# get list of argo meta files
argolist = []
for file in os.listdir(argo_path):
    if file.endswith('meta.nc'):
        argolist.append(file)

print(len(argolist))
# Out:
# 1839

# %%
cal_str_table = pd.DataFrame(columns=['wmo','o2_cal_comment', 'o2_cal_eq'])
# temp_list = ['3902471_meta.nc']
# loop through all, open meta files, read in calibration comments, store
for n, file in enumerate(argolist): #enumerate(temp_list): # 
    print(str(n) + ' ' + file)


    #also load meta file  for same float
    file_n = argo_path + file
    meta_n = xr.open_dataset(argo_path + file)
    # meta_n
    parameters_n = meta_n.PARAMETER.values
    # print(parameters_n)

    contains_doxy = any(parameter.decode('utf-8').strip() == 'DOXY' for parameter in parameters_n)
    if contains_doxy is False:
        continue
        print('no doxy')

    # not sure if i need this, but loading the Sprof file as well

    wmo_n = int((re.search(r'\d+', file)).group())

    
    sprof_n = xr.open_dataset(argo_path + str(wmo_n) + '_Sprof.nc')

    n_prof = sprof_n.dims['N_PROF']
    # gets order of sensors to extract calibration comments
    # some profiles might be missing sensor name (not sure why) so loop through looking
    o2_ind_all = np.full(n_prof, np.nan)
    # finds where o2 calibration comment is in each profile (at least for one float it changes from the first profile to the rest)
    for p in range(0, n_prof):
        cal_str = sprof_n.STATION_PARAMETERS.values.astype(str)[p]
        # print(cal_str)
        for i, param in enumerate(cal_str):
            if 'DOXY' in param:
                o2_ind_all[p] = i
                break
    
    # o2_ind = np.unique(o2_ind_all[~np.isnan(o2_ind_all)])
    # if len(o2_ind)>1:
    #     print('multiple o2 ind' + str(wmo_n))
    #     break
    o2_cal_full = []
    o2_eq_full = []

    for idx, o2_ind in enumerate(o2_ind_all):
        if ~np.isnan(o2_ind):
            o2_cal_full.append(sprof_n.SCIENTIFIC_CALIB_COMMENT.values[idx,-1,np.int32(o2_ind)])
            # pd.concat([o2_cal_full]+ sprof_n.SCIENTIFIC_CALIB_COMMENT.values[idx,-1,np.int32(o2_ind)], ignore_index=True)
            o2_eq_full.append(sprof_n.SCIENTIFIC_CALIB_EQUATION.values[idx,-1,np.int32(o2_ind)])

    data_comment_eq = pd.DataFrame({'o2_cal_full': o2_cal_full, 'o2_eq_full': o2_eq_full})

    # Drop duplicate rows to get unique pairs
    unique_pairs = data_comment_eq.drop_duplicates()
    # Create an empty list to store DataFrames
    data_frames = []
    # print(o2_cal_unique)
    # might have multiple unique comments, so save out each one:
    for i in unique_pairs.index:
        o2_cal_i = unique_pairs.o2_cal_full[i].decode("utf-8")
        o2_eq_i = unique_pairs.o2_eq_full[i].decode("utf-8")

        # print(o2_cal_i)
        # save with wmo only for now
        new_data_cal_info = pd.DataFrame({'wmo': [wmo_n],
                                        'o2_cal_comment': [o2_cal_i],
                                        'o2_cal_eq': [o2_eq_i]})
        # Append the new_data_cal_info DataFrame to the list
        data_frames.append(new_data_cal_info)

        # cal_str_table = cal_str_table.append(new_data_cal_info, ignore_index=True)
    # print(data_frames)
    # Concatenate all DataFrames in the list into a single DataFrame
    cal_str_table = pd.concat([cal_str_table] + data_frames, ignore_index=True)
    # print(cal_str_table)
    # if n==10:
    #     break
    # if wmo_n== 3902471:
    #     break
print(cal_str_table)
# Out:
# 0 4901216_meta.nc
# 1 7901019_meta.nc
# 2 5904485_meta.nc
# 3 6903878_meta.nc
# 4 7901009_meta.nc
# 5 3902471_meta.nc
# 6 6900874_meta.nc
# 7 2900787_meta.nc
# 8 5906972_meta.nc
# 9 5905381_meta.nc
# 10 5906042_meta.nc
# 11 6902734_meta.nc
# 12 2903454_meta.nc
# 13 6902019_meta.nc
# 14 6902980_meta.nc
# 15 1901153_meta.nc
# 16 5901739_meta.nc
# 17 5906571_meta.nc
# 18 2903167_meta.nc
# 19 5906561_meta.nc
# 20 2902238_meta.nc
# 21 5905136_meta.nc
# 22 4900869_meta.nc
# 23 6903030_meta.nc
# 24 5901372_meta.nc
# 25 2900448_meta.nc
# 26 4900879_meta.nc
# 27 6903042_meta.nc
# 28 2900542_meta.nc
# 29 6902548_meta.nc
# 30 5902112_meta.nc
# 31 6901632_meta.nc
# 32 5901310_meta.nc
# 33 5906513_meta.nc
# 34 6901896_meta.nc
# 35 5906503_meta.nc
# 36 6901886_meta.nc
# 37 6903571_meta.nc
# 38 2900119_meta.nc
# 39 5906020_meta.nc
# 40 5905232_meta.nc
# 41 5906030_meta.nc
# 42 5903616_meta.nc
# 43 3902130_meta.nc
# 44 3902120_meta.nc
# 45 4902555_meta.nc
# 46 6901485_meta.nc
# 47 6902687_meta.nc
# 48 2902195_meta.nc
# 49 5906868_meta.nc
# 50 5905095_meta.nc
# 51 4902633_meta.nc
# 52 6903183_meta.nc
# 53 7900561_meta.nc
# 54 4902623_meta.nc
# 55 5906297_meta.nc
# 56 1901362_meta.nc
# 57 6901152_meta.nc
# 58 5906436_meta.nc
# 59 5905634_meta.nc
# 60 6900530_meta.nc
# 61 5901460_meta.nc
# 62 2902442_meta.nc
# 63 5905071_meta.nc
# 64 4900856_meta.nc
# 65 5905109_meta.nc
# 66 7900585_meta.nc
# 67 2902217_meta.nc
# 68 6901519_meta.nc
# 69 5904765_meta.nc
# 70 6901461_meta.nc
# 71 5903723_meta.nc
# 72 2902161_meta.nc
# 73 6901471_meta.nc
# 74 1902453_meta.nc
# 75 2902734_meta.nc
# 76 5900588_meta.nc
# 77 6902906_meta.nc
# 78 4903657_meta.nc
# 79 3902005_meta.nc
# 80 6900797_meta.nc
# 81 5904397_meta.nc
# 82 4903459_meta.nc
# 83 3900346_meta.nc
# 84 5903594_meta.nc
# 85 6904188_meta.nc
# 86 6903825_meta.nc
# 87 3900334_meta.nc
# 88 5904093_meta.nc
# 89 6902964_meta.nc
# 90 4901045_meta.nc
# 91 6902974_meta.nc
# 92 4903625_meta.nc
# 93 2902823_meta.nc
# 94 2902833_meta.nc
# 95 5901188_meta.nc
# 96 4902386_meta.nc
# 97 7900825_meta.nc
# 98 2902756_meta.nc
# 99 2901554_meta.nc
# 100 2900126_meta.nc
# 101 2902746_meta.nc
# 102 5905375_meta.nc
# 103 5903741_meta.nc
# 104 6903263_meta.nc
# 105 6900890_meta.nc
# 106 5901049_meta.nc
# 107 5903629_meta.nc
# 108 6903273_meta.nc
# 109 6904235_meta.nc
# 110 2902113_meta.nc
# 111 6901765_meta.nc
# 112 5906201_meta.nc
# 113 2902275_meta.nc
# 114 5906211_meta.nc
# 115 6901775_meta.nc
# 116 5904471_meta.nc
# 117 5903272_meta.nc
# 118 5906444_meta.nc
# 119 2902243_meta.nc
# 120 5906227_meta.nc
# 121 2901041_meta.nc
# 122 6901753_meta.nc
# 123 5906237_meta.nc
# 124 5906472_meta.nc
# 125 6903568_meta.nc
# 126 2901562_meta.nc
# 127 6902883_meta.nc
# 128 6903578_meta.nc
# 129 6902893_meta.nc
# 130 5901742_meta.nc
# 131 5904659_meta.nc
# 132 5906039_meta.nc
# 133 5902305_meta.nc
# 134 5904854_meta.nc
# 135 3902129_meta.nc
# 136 1902383_meta.nc
# 137 7900133_meta.nc
# 138 5904844_meta.nc
# 139 6903803_meta.nc
# 140 5900966_meta.nc
# 141 5903385_meta.nc
# 142 5905977_meta.nc
# 143 3902500_meta.nc
# 144 6903080_meta.nc
# 145 2902298_meta.nc
# 146 6903090_meta.nc
# 147 6903871_meta.nc
# 148 5904682_meta.nc
# 149 2902086_meta.nc
# 150 6901596_meta.nc
# 151 5904692_meta.nc
# 152 4902597_meta.nc
# 153 4901785_meta.nc
# 154 5901165_meta.nc
# 155 2900727_meta.nc
# 156 2900737_meta.nc
# 157 6903237_meta.nc
# 158 6901457_meta.nc
# 159 2900993_meta.nc
# 160 5901648_meta.nc
# 161 3900792_meta.nc
# 162 5901730_meta.nc
# 163 5904106_meta.nc
# 164 5906766_meta.nc
# 165 2903006_meta.nc
# 166 5906568_meta.nc
# 167 5901456_meta.nc
# 168 6901174_meta.nc
# 169 5906578_meta.nc
# 170 5903226_meta.nc
# 171 6903704_meta.nc
# 172 5901446_meta.nc
# 173 6903039_meta.nc
# 174 6901659_meta.nc
# 175 2903653_meta.nc
# 176 4900870_meta.nc
# 177 5906245_meta.nc
# 178 1901501_meta.nc
# 179 6901649_meta.nc
# 180 6903029_meta.nc
# 181 6904117_meta.nc
# 182 6901180_meta.nc
# 183 5903955_meta.nc
# 184 4901134_meta.nc
# 185 6902805_meta.nc
# 186 3902116_meta.nc
# 187 2903394_meta.nc
# 188 3902106_meta.nc
# 189 6902815_meta.nc
# 190 6903557_meta.nc
# 191 5904033_meta.nc
# 192 5905441_meta.nc
# 193 4900487_meta.nc
# 194 4900497_meta.nc
# 195 4901804_meta.nc
# 196 5904666_meta.nc
# 197 5906006_meta.nc
# 198 6900889_meta.nc
# 199 2902883_meta.nc
# 200 5903630_meta.nc
# 201 5901050_meta.nc
# 202 5904676_meta.nc
# 203 5900422_meta.nc
# 204 6901604_meta.nc
# 205 5905993_meta.nc
# 206 5906218_meta.nc
# 207 5904478_meta.nc
# 208 5901336_meta.nc
# 209 5905983_meta.nc
# 210 5904468_meta.nc
# 211 5906208_meta.nc
# 212 5906535_meta.nc
# 213 5906525_meta.nc
# 214 2902439_meta.nc
# 215 5906557_meta.nc
# 216 6900529_meta.nc
# 217 5906547_meta.nc
# 218 6901023_meta.nc
# 219 1901213_meta.nc
# 220 5905068_meta.nc
# 221 5906302_meta.nc
# 222 5906312_meta.nc
# 223 5905078_meta.nc
# 224 5905100_meta.nc
# 225 2902178_meta.nc
# 226 2901212_meta.nc
# 227 6901510_meta.nc
# 228 6901468_meta.nc
# 229 5902299_meta.nc
# 230 2900915_meta.nc
# 231 4900524_meta.nc
# 232 3900714_meta.nc
# 233 5904180_meta.nc
# 234 3901999_meta.nc
# 235 5906496_meta.nc
# 236 4900652_meta.nc
# 237 5906486_meta.nc
# 238 7900132_meta.nc
# 239 5904845_meta.nc
# 240 1902382_meta.nc
# 241 6902953_meta.nc
# 242 5904855_meta.nc
# 243 3902128_meta.nc
# 244 7900579_meta.nc
# 245 6903802_meta.nc
# 246 6903767_meta.nc
# 247 5906473_meta.nc
# 248 5903255_meta.nc
# 249 6903777_meta.nc
# 250 5906236_meta.nc
# 251 6901752_meta.nc
# 252 5906226_meta.nc
# 253 2902242_meta.nc
# 254 6902550_meta.nc
# 255 5906028_meta.nc
# 256 5902304_meta.nc
# 257 2902124_meta.nc
# 258 5904658_meta.nc
# 259 6902892_meta.nc
# 260 5904165_meta.nc
# 261 5901743_meta.nc
# 262 5904984_meta.nc
# 263 6903579_meta.nc
# 264 6902882_meta.nc
# 265 2901563_meta.nc
# 266 6903569_meta.nc
# 267 5904107_meta.nc
# 268 5906767_meta.nc
# 269 2903209_meta.nc
# 270 3900793_meta.nc
# 271 5901731_meta.nc
# 272 7900918_meta.nc
# 273 2900736_meta.nc
# 274 2902156_meta.nc
# 275 5903714_meta.nc
# 276 4901784_meta.nc
# 277 4902596_meta.nc
# 278 6904116_meta.nc
# 279 6901648_meta.nc
# 280 6903028_meta.nc
# 281 4900871_meta.nc
# 282 5906244_meta.nc
# 283 1901468_meta.nc
# 284 6903038_meta.nc
# 285 2903652_meta.nc
# 286 6901658_meta.nc
# 287 5901447_meta.nc
# 288 5906579_meta.nc
# 289 5901457_meta.nc
# 290 6901175_meta.nc
# 291 5906569_meta.nc
# 292 2903007_meta.nc
# 293 6903870_meta.nc
# 294 2903783_meta.nc
# 295 6903091_meta.nc
# 296 2902299_meta.nc
# 297 5905197_meta.nc
# 298 6903081_meta.nc
# 299 7901001_meta.nc
# 300 3900524_meta.nc
# 301 3900534_meta.nc
# 302 6902931_meta.nc
# 303 6901597_meta.nc
# 304 5904693_meta.nc
# 305 5904683_meta.nc
# 306 2902087_meta.nc
# 307 6901573_meta.nc
# 308 5904677_meta.nc
# 309 5901051_meta.nc
# 310 2902882_meta.nc
# 311 5904667_meta.nc
# 312 2900603_meta.nc
# 313 5906007_meta.nc
# 314 4901805_meta.nc
# 315 1902304_meta.nc
# 316 5904032_meta.nc
# 317 6903556_meta.nc
# 318 2902438_meta.nc
# 319 5906524_meta.nc
# 320 5906534_meta.nc
# 321 5904469_meta.nc
# 322 5906209_meta.nc
# 323 5901337_meta.nc
# 324 5905982_meta.nc
# 325 5906219_meta.nc
# 326 5904479_meta.nc
# 327 5905992_meta.nc
# 328 6903065_meta.nc
# 329 6901181_meta.nc
# 330 6903699_meta.nc
# 331 5900958_meta.nc
# 332 6902814_meta.nc
# 333 2903395_meta.nc
# 334 6902804_meta.nc
# 335 4901135_meta.nc
# 336 3902117_meta.nc
# 337 5903954_meta.nc
# 338 6902876_meta.nc
# 339 5904181_meta.nc
# 340 3900715_meta.nc
# 341 2900914_meta.nc
# 342 5902298_meta.nc
# 343 5906487_meta.nc
# 344 5906497_meta.nc
# 345 3901998_meta.nc
# 346 5905101_meta.nc
# 347 5906313_meta.nc
# 348 5905079_meta.nc
# 349 5905111_meta.nc
# 350 6904139_meta.nc
# 351 5905069_meta.nc
# 352 5906303_meta.nc
# 353 5903218_meta.nc
# 354 1901212_meta.nc
# 355 6901022_meta.nc
# 356 5906546_meta.nc
# 357 6900528_meta.nc
# 358 5901468_meta.nc
# 359 5906556_meta.nc
# 360 6901032_meta.nc
# 361 5904128_meta.nc
# 362 2902179_meta.nc
# 363 1901152_meta.nc
# 364 2903210_meta.nc
# 365 5901738_meta.nc
# 366 6902018_meta.nc
# 367 6902981_meta.nc
# 368 6902735_meta.nc
# 369 5906043_meta.nc
# 370 2900449_meta.nc
# 371 5901373_meta.nc
# 372 6903031_meta.nc
# 373 2902239_meta.nc
# 374 5905137_meta.nc
# 375 2903176_meta.nc
# 376 5906560_meta.nc
# 377 6901004_meta.nc
# 378 2903166_meta.nc
# 379 5906570_meta.nc
# 380 6903869_meta.nc
# 381 6903088_meta.nc
# 382 5904484_meta.nc
# 383 4903711_meta.nc
# 384 5905380_meta.nc
# 385 2900786_meta.nc
# 386 6903286_meta.nc
# 387 6900875_meta.nc
# 388 6900807_meta.nc
# 389 6902686_meta.nc
# 390 6901484_meta.nc
# 391 4902554_meta.nc
# 392 3902121_meta.nc
# 393 2900940_meta.nc
# 394 5904924_meta.nc
# 395 3902131_meta.nc
# 396 4900607_meta.nc
# 397 5906296_meta.nc
# 398 7900560_meta.nc
# 399 5905094_meta.nc
# 400 5906502_meta.nc
# 401 6901897_meta.nc
# 402 5906512_meta.nc
# 403 5901311_meta.nc
# 404 5902113_meta.nc
# 405 6902549_meta.nc
# 406 1902601_meta.nc
# 407 5905223_meta.nc
# 408 5902265_meta.nc
# 409 5906031_meta.nc
# 410 5906021_meta.nc
# 411 2900118_meta.nc
# 412 1902332_meta.nc
# 413 6903570_meta.nc
# 414 6900796_meta.nc
# 415 3902004_meta.nc
# 416 5904188_meta.nc
# 417 6902907_meta.nc
# 418 1902593_meta.nc
# 419 5902291_meta.nc
# 420 6904189_meta.nc
# 421 4903365_meta.nc
# 422 3900347_meta.nc
# 423 4903458_meta.nc
# 424 5904396_meta.nc
# 425 2902216_meta.nc
# 426 5905108_meta.nc
# 427 5905070_meta.nc
# 428 7900594_meta.nc
# 429 5901461_meta.nc
# 430 2902443_meta.nc
# 431 5905635_meta.nc
# 432 6900531_meta.nc
# 433 5906437_meta.nc
# 434 1901363_meta.nc
# 435 2902735_meta.nc
# 436 6901235_meta.nc
# 437 2901527_meta.nc
# 438 6902027_meta.nc
# 439 6901470_meta.nc
# 440 5904764_meta.nc
# 441 6903200_meta.nc
# 442 2902160_meta.nc
# 443 5903722_meta.nc
# 444 6901460_meta.nc
# 445 3901498_meta.nc
# 446 5901048_meta.nc
# 447 6900891_meta.nc
# 448 6903262_meta.nc
# 449 5905374_meta.nc
# 450 2900127_meta.nc
# 451 2902747_meta.nc
# 452 2901555_meta.nc
# 453 5905531_meta.nc
# 454 2902757_meta.nc
# 455 7900824_meta.nc
# 456 2902431_meta.nc
# 457 6990528_meta.nc
# 458 6901774_meta.nc
# 459 5906210_meta.nc
# 460 2902274_meta.nc
# 461 5904470_meta.nc
# 462 6901764_meta.nc
# 463 2902264_meta.nc
# 464 6903824_meta.nc
# 465 2902832_meta.nc
# 466 2902822_meta.nc
# 467 4901779_meta.nc
# 468 6902975_meta.nc
# 469 4903624_meta.nc
# 470 4903634_meta.nc
# 471 5904092_meta.nc
# 472 6902965_meta.nc
# 473 5901455_meta.nc
# 474 1901347_meta.nc
# 475 6903707_meta.nc
# 476 5901445_meta.nc
# 477 5903225_meta.nc
# 478 5906246_meta.nc
# 479 4900873_meta.nc
# 480 2903650_meta.nc
# 481 6903152_meta.nc
# 482 6904114_meta.nc
# 483 4901786_meta.nc
# 484 2900734_meta.nc
# 485 5901733_meta.nc
# 486 3900791_meta.nc
# 487 1901159_meta.nc
# 488 5906765_meta.nc
# 489 2902701_meta.nc
# 490 5904105_meta.nc
# 491 6901585_meta.nc
# 492 5904691_meta.nc
# 493 6901595_meta.nc
# 494 3900728_meta.nc
# 495 4903672_meta.nc
# 496 6902933_meta.nc
# 497 4901459_meta.nc
# 498 6903083_meta.nc
# 499 5905974_meta.nc
# 500 3901669_meta.nc
# 501 6903872_meta.nc
# 502 6903093_meta.nc
# 503 7901013_meta.nc
# 504 5900965_meta.nc
# 505 5904857_meta.nc
# 506 5904847_meta.nc
# 507 6902829_meta.nc
# 508 1902380_meta.nc
# 509 4902437_meta.nc
# 510 6902880_meta.nc
# 511 5905505_meta.nc
# 512 2901561_meta.nc
# 513 5901741_meta.nc
# 514 5904167_meta.nc
# 515 6902890_meta.nc
# 516 6903246_meta.nc
# 517 5902306_meta.nc
# 518 2902240_meta.nc
# 519 5906224_meta.nc
# 520 6901750_meta.nc
# 521 6903130_meta.nc
# 522 6901628_meta.nc
# 523 2901042_meta.nc
# 524 5903257_meta.nc
# 525 5906471_meta.nc
# 526 5906509_meta.nc
# 527 6903765_meta.nc
# 528 5906519_meta.nc
# 529 5906495_meta.nc
# 530 5906485_meta.nc
# 531 6903781_meta.nc
# 532 4900651_meta.nc
# 533 6901900_meta.nc
# 534 6904182_meta.nc
# 535 3901530_meta.nc
# 536 3900717_meta.nc
# 537 2900916_meta.nc
# 538 5904183_meta.nc
# 539 6902874_meta.nc
# 540 1902459_meta.nc
# 541 2901211_meta.nc
# 542 6902669_meta.nc
# 543 6902701_meta.nc
# 544 2902448_meta.nc
# 545 1901378_meta.nc
# 546 2902530_meta.nc
# 547 6901030_meta.nc
# 548 5906554_meta.nc
# 549 1901210_meta.nc
# 550 5906544_meta.nc
# 551 2901177_meta.nc
# 552 5905113_meta.nc
# 553 5906301_meta.nc
# 554 5905103_meta.nc
# 555 5906311_meta.nc
# 556 6903067_meta.nc
# 557 5905980_meta.nc
# 558 4903488_meta.nc
# 559 5906536_meta.nc
# 560 5906526_meta.nc
# 561 4900484_meta.nc
# 562 5905442_meta.nc
# 563 7900947_meta.nc
# 564 6903554_meta.nc
# 565 5904030_meta.nc
# 566 5903887_meta.nc
# 567 4900494_meta.nc
# 568 5906005_meta.nc
# 569 5901043_meta.nc
# 570 5904665_meta.nc
# 571 5900421_meta.nc
# 572 5901053_meta.nc
# 573 5904675_meta.nc
# 574 3902115_meta.nc
# 575 4901137_meta.nc
# 576 6902806_meta.nc
# 577 5904089_meta.nc
# 578 5903956_meta.nc
# 579 6902816_meta.nc
# 580 2902829_meta.nc
# 581 4902616_meta.nc
# 582 4903274_meta.nc
# 583 6900499_meta.nc
# 584 6901183_meta.nc
# 585 6903180_meta.nc
# 586 1900943_meta.nc
# 587 5905096_meta.nc
# 588 4902630_meta.nc
# 589 5906294_meta.nc
# 590 6903190_meta.nc
# 591 6901688_meta.nc
# 592 7900562_meta.nc
# 593 4902620_meta.nc
# 594 6902820_meta.nc
# 595 6902958_meta.nc
# 596 3902123_meta.nc
# 597 5901699_meta.nc
# 598 6901486_meta.nc
# 599 2902196_meta.nc
# 600 6901496_meta.nc
# 601 6900760_meta.nc
# 602 6903572_meta.nc
# 603 6902889_meta.nc
# 604 5902267_meta.nc
# 605 5906033_meta.nc
# 606 5903615_meta.nc
# 607 6901759_meta.nc
# 608 1902603_meta.nc
# 609 6903041_meta.nc
# 610 2900541_meta.nc
# 611 5902101_meta.nc
# 612 6901749_meta.nc
# 613 5901313_meta.nc
# 614 6901631_meta.nc
# 615 5906468_meta.nc
# 616 6901895_meta.nc
# 617 5906510_meta.nc
# 618 5904218_meta.nc
# 619 6990505_meta.nc
# 620 5906478_meta.nc
# 621 5906500_meta.nc
# 622 5906572_meta.nc
# 623 2903174_meta.nc
# 624 5906562_meta.nc
# 625 5905135_meta.nc
# 626 6903033_meta.nc
# 627 6902737_meta.nc
# 628 5906041_meta.nc
# 629 5903677_meta.nc
# 630 6902983_meta.nc
# 631 2903212_meta.nc
# 632 2900999_meta.nc
# 633 6900877_meta.nc
# 634 2900784_meta.nc
# 635 2900794_meta.nc
# 636 5904688_meta.nc
# 637 5906971_meta.nc
# 638 5905382_meta.nc
# 639 3902462_meta.nc
# 640 5904486_meta.nc
# 641 3902472_meta.nc
# 642 6901766_meta.nc
# 643 5906202_meta.nc
# 644 2903614_meta.nc
# 645 5904472_meta.nc
# 646 2902276_meta.nc
# 647 5906212_meta.nc
# 648 6901776_meta.nc
# 649 2902433_meta.nc
# 650 5904227_meta.nc
# 651 7900826_meta.nc
# 652 2902755_meta.nc
# 653 5904029_meta.nc
# 654 6900627_meta.nc
# 655 2900125_meta.nc
# 656 2901557_meta.nc
# 657 6904226_meta.nc
# 658 5903742_meta.nc
# 659 5905376_meta.nc
# 660 6901578_meta.nc
# 661 5905366_meta.nc
# 662 2900608_meta.nc
# 663 6902967_meta.nc
# 664 5904090_meta.nc
# 665 6902977_meta.nc
# 666 2902830_meta.nc
# 667 6903826_meta.nc
# 668 3901078_meta.nc
# 669 3901068_meta.nc
# 670 4903532_meta.nc
# 671 3900345_meta.nc
# 672 6900784_meta.nc
# 673 6902905_meta.nc
# 674 3902006_meta.nc
# 675 6901462_meta.nc
# 676 5903720_meta.nc
# 677 2901208_meta.nc
# 678 5904766_meta.nc
# 679 6902670_meta.nc
# 680 6901472_meta.nc
# 681 6902025_meta.nc
# 682 6901151_meta.nc
# 683 5906435_meta.nc
# 684 2902529_meta.nc
# 685 1901361_meta.nc
# 686 6901029_meta.nc
# 687 2902441_meta.nc
# 688 1901209_meta.nc
# 689 4901283_meta.nc
# 690 5901463_meta.nc
# 691 5905637_meta.nc
# 692 2902204_meta.nc
# 693 7900596_meta.nc
# 694 5905072_meta.nc
# 695 5906318_meta.nc
# 696 4900845_meta.nc
# 697 5906308_meta.nc
# 698 2903666_meta.nc
# 699 5905062_meta.nc
# 700 7900586_meta.nc
# 701 5903614_meta.nc
# 702 5906032_meta.nc
# 703 5902266_meta.nc
# 704 6902888_meta.nc
# 705 6903573_meta.nc
# 706 5906501_meta.nc
# 707 5906479_meta.nc
# 708 6990504_meta.nc
# 709 5906511_meta.nc
# 710 5906469_meta.nc
# 711 6901748_meta.nc
# 712 5902100_meta.nc
# 713 2900540_meta.nc
# 714 6903040_meta.nc
# 715 1902602_meta.nc
# 716 5902110_meta.nc
# 717 6901758_meta.nc
# 718 6901689_meta.nc
# 719 7900563_meta.nc
# 720 5906295_meta.nc
# 721 6903191_meta.nc
# 722 5905097_meta.nc
# 723 6903818_meta.nc
# 724 6900804_meta.nc
# 725 6901487_meta.nc
# 726 5901698_meta.nc
# 727 3902122_meta.nc
# 728 6902959_meta.nc
# 729 3902132_meta.nc
# 730 3900730_meta.nc
# 731 4900345_meta.nc
# 732 5905383_meta.nc
# 733 5906970_meta.nc
# 734 5904689_meta.nc
# 735 2900795_meta.nc
# 736 2900785_meta.nc
# 737 6900876_meta.nc
# 738 5904487_meta.nc
# 739 3902463_meta.nc
# 740 6901652_meta.nc
# 741 5901370_meta.nc
# 742 6903032_meta.nc
# 743 2903648_meta.nc
# 744 6900348_meta.nc
# 745 5905134_meta.nc
# 746 5906563_meta.nc
# 747 2903175_meta.nc
# 748 5906573_meta.nc
# 749 2901705_meta.nc
# 750 2903165_meta.nc
# 751 2900998_meta.nc
# 752 2903213_meta.nc
# 753 6902982_meta.nc
# 754 5906040_meta.nc
# 755 6902736_meta.nc
# 756 2902831_meta.nc
# 757 6900953_meta.nc
# 758 4902410_meta.nc
# 759 6902976_meta.nc
# 760 5904860_meta.nc
# 761 6902966_meta.nc
# 762 5904091_meta.nc
# 763 5900952_meta.nc
# 764 3901079_meta.nc
# 765 5903260_meta.nc
# 766 2902432_meta.nc
# 767 5905998_meta.nc
# 768 5904473_meta.nc
# 769 5906213_meta.nc
# 770 2902277_meta.nc
# 771 5905988_meta.nc
# 772 2903615_meta.nc
# 773 5906203_meta.nc
# 774 6901767_meta.nc
# 775 2900609_meta.nc
# 776 5905367_meta.nc
# 777 5903753_meta.nc
# 778 5905377_meta.nc
# 779 6901579_meta.nc
# 780 5903743_meta.nc
# 781 2901556_meta.nc
# 782 2900124_meta.nc
# 783 5904028_meta.nc
# 784 4902384_meta.nc
# 785 2902754_meta.nc
# 786 7900827_meta.nc
# 787 2903354_meta.nc
# 788 6902024_meta.nc
# 789 2902736_meta.nc
# 790 5904132_meta.nc
# 791 5903649_meta.nc
# 792 6901473_meta.nc
# 793 6902671_meta.nc
# 794 5903721_meta.nc
# 795 6901463_meta.nc
# 796 5904767_meta.nc
# 797 6903203_meta.nc
# 798 2901209_meta.nc
# 799 2903667_meta.nc
# 800 5906309_meta.nc
# 801 7900587_meta.nc
# 802 2902215_meta.nc
# 803 5905073_meta.nc
# 804 5906319_meta.nc
# 805 2902205_meta.nc
# 806 6900532_meta.nc
# 807 5905636_meta.nc
# 808 1901208_meta.nc
# 809 2902440_meta.nc
# 810 5901462_meta.nc
# 811 6901028_meta.nc
# 812 1901360_meta.nc
# 813 5906434_meta.nc
# 814 2902450_meta.nc
# 815 1901218_meta.nc
# 816 5903586_meta.nc
# 817 3900344_meta.nc
# 818 6903799_meta.nc
# 819 5904395_meta.nc
# 820 4903533_meta.nc
# 821 3902007_meta.nc
# 822 6902904_meta.nc
# 823 6900785_meta.nc
# 824 3900729_meta.nc
# 825 5906969_meta.nc
# 826 5904690_meta.nc
# 827 3901466_meta.nc
# 828 6901584_meta.nc
# 829 4903026_meta.nc
# 830 5904680_meta.nc
# 831 6903873_meta.nc
# 832 6903082_meta.nc
# 833 3901668_meta.nc
# 834 5905975_meta.nc
# 835 5905194_meta.nc
# 836 4901458_meta.nc
# 837 5901369_meta.nc
# 838 6903153_meta.nc
# 839 6904115_meta.nc
# 840 2903651_meta.nc
# 841 4900093_meta.nc
# 842 5906247_meta.nc
# 843 4900872_meta.nc
# 844 2903014_meta.nc
# 845 5901444_meta.nc
# 846 6903706_meta.nc
# 847 3901084_meta.nc
# 848 5901454_meta.nc
# 849 5904104_meta.nc
# 850 1901158_meta.nc
# 851 7900863_meta.nc
# 852 5903717_meta.nc
# 853 2900735_meta.nc
# 854 6903225_meta.nc
# 855 5902307_meta.nc
# 856 6901437_meta.nc
# 857 6903247_meta.nc
# 858 5905229_meta.nc
# 859 5904166_meta.nc
# 860 5901740_meta.nc
# 861 2902762_meta.nc
# 862 2901560_meta.nc
# 863 6902881_meta.nc
# 864 5906518_meta.nc
# 865 5906508_meta.nc
# 866 5906470_meta.nc
# 867 5903256_meta.nc
# 868 2901043_meta.nc
# 869 5906235_meta.nc
# 870 6901751_meta.nc
# 871 5906225_meta.nc
# 872 5902109_meta.nc
# 873 2902241_meta.nc
# 874 4902628_meta.nc
# 875 1902381_meta.nc
# 876 6902828_meta.nc
# 877 5904846_meta.nc
# 878 5904856_meta.nc
# 879 5906623_meta.nc
# 880 6901512_meta.nc
# 881 6902700_meta.nc
# 882 6902668_meta.nc
# 883 2901210_meta.nc
# 884 2900514_meta.nc
# 885 5906310_meta.nc
# 886 5905102_meta.nc
# 887 5906300_meta.nc
# 888 5905112_meta.nc
# 889 6901021_meta.nc
# 890 5906545_meta.nc
# 891 1901211_meta.nc
# 892 1901379_meta.nc
# 893 2902449_meta.nc
# 894 6904183_meta.nc
# 895 5906484_meta.nc
# 896 5900841_meta.nc
# 897 5906494_meta.nc
# 898 5904182_meta.nc
# 899 6902875_meta.nc
# 900 2900917_meta.nc
# 901 3900716_meta.nc
# 902 3901531_meta.nc
# 903 4902409_meta.nc
# 904 2903396_meta.nc
# 905 3902104_meta.nc
# 906 5903957_meta.nc
# 907 3902114_meta.nc
# 908 6902807_meta.nc
# 909 4901136_meta.nc
# 910 6901182_meta.nc
# 911 5906527_meta.nc
# 912 4903499_meta.nc
# 913 5906537_meta.nc
# 914 4903489_meta.nc
# 915 5905981_meta.nc
# 916 6903066_meta.nc
# 917 5905991_meta.nc
# 918 5904674_meta.nc
# 919 2900610_meta.nc
# 920 5901052_meta.nc
# 921 6903268_meta.nc
# 922 5900420_meta.nc
# 923 5906004_meta.nc
# 924 5904664_meta.nc
# 925 5901042_meta.nc
# 926 2902118_meta.nc
# 927 2902881_meta.nc
# 928 5904021_meta.nc
# 929 4901806_meta.nc
# 930 5904031_meta.nc
# 931 6903555_meta.nc
# 932 4900485_meta.nc
# 933 5906305_meta.nc
# 934 5906315_meta.nc
# 935 2902209_meta.nc
# 936 5905107_meta.nc
# 937 5906550_meta.nc
# 938 6901024_meta.nc
# 939 5906540_meta.nc
# 940 5906438_meta.nc
# 941 1901214_meta.nc
# 942 5906636_meta.nc
# 943 2901528_meta.nc
# 944 6902028_meta.nc
# 945 4900523_meta.nc
# 946 6900799_meta.nc
# 947 3900713_meta.nc
# 948 6902908_meta.nc
# 949 6902870_meta.nc
# 950 4901141_meta.nc
# 951 5904187_meta.nc
# 952 6904186_meta.nc
# 953 7901028_meta.nc
# 954 3900348_meta.nc
# 955 5906491_meta.nc
# 956 3901065_meta.nc
# 957 4900627_meta.nc
# 958 3901075_meta.nc
# 959 4900637_meta.nc
# 960 4902612_meta.nc
# 961 4902602_meta.nc
# 962 4900883_meta.nc
# 963 6902802_meta.nc
# 964 3902111_meta.nc
# 965 2903393_meta.nc
# 966 3902101_meta.nc
# 967 6902812_meta.nc
# 968 5904661_meta.nc
# 969 2900605_meta.nc
# 970 5901047_meta.nc
# 971 5906001_meta.nc
# 972 3901497_meta.nc
# 973 5904671_meta.nc
# 974 5904034_meta.nc
# 975 6903550_meta.nc
# 976 7900943_meta.nc
# 977 5903893_meta.nc
# 978 2900128_meta.nc
# 979 4900480_meta.nc
# 980 5904024_meta.nc
# 981 2902758_meta.nc
# 982 4901803_meta.nc
# 983 2901744_meta.nc
# 984 5906522_meta.nc
# 985 5905994_meta.nc
# 986 6901603_meta.nc
# 987 5905984_meta.nc
# 988 5905165_meta.nc
# 989 5905970_meta.nc
# 990 7901007_meta.nc
# 991 2903795_meta.nc
# 992 6903876_meta.nc
# 993 3900532_meta.nc
# 994 4903500_meta.nc
# 995 3900522_meta.nc
# 996 6902937_meta.nc
# 997 4900474_meta.nc
# 998 5904685_meta.nc
# 999 6901581_meta.nc
# 1000 2902091_meta.nc
# 1001 5904695_meta.nc
# 1002 2900789_meta.nc
# 1003 5900345_meta.nc
# 1004 5901737_meta.nc
# 1005 4901782_meta.nc
# 1006 6901440_meta.nc
# 1007 6901528_meta.nc
# 1008 2900730_meta.nc
# 1009 5903712_meta.nc
# 1010 2903654_meta.nc
# 1011 2900446_meta.nc
# 1012 6904110_meta.nc
# 1013 5905138_meta.nc
# 1014 3901081_meta.nc
# 1015 5901451_meta.nc
# 1016 2903011_meta.nc
# 1017 2903169_meta.nc
# 1018 5906475_meta.nc
# 1019 6901888_meta.nc
# 1020 6901898_meta.nc
# 1021 5906220_meta.nc
# 1022 2902244_meta.nc
# 1023 6903124_meta.nc
# 1024 6902546_meta.nc
# 1025 5905022_meta.nc
# 1026 5906230_meta.nc
# 1027 6901754_meta.nc
# 1028 1902578_meta.nc
# 1029 5902302_meta.nc
# 1030 2901565_meta.nc
# 1031 5905501_meta.nc
# 1032 2900117_meta.nc
# 1033 6902884_meta.nc
# 1034 5904982_meta.nc
# 1035 6902894_meta.nc
# 1036 5906866_meta.nc
# 1037 3901579_meta.nc
# 1038 5904853_meta.nc
# 1039 1902384_meta.nc
# 1040 5904843_meta.nc
# 1041 5900961_meta.nc
# 1042 5903382_meta.nc
# 1043 4900608_meta.nc
# 1044 7901065_meta.nc
# 1045 6903804_meta.nc
# 1046 5906582_meta.nc
# 1047 6903822_meta.nc
# 1048 7900559_meta.nc
# 1049 3900333_meta.nc
# 1050 2902834_meta.nc
# 1051 5904094_meta.nc
# 1052 6902963_meta.nc
# 1053 6902973_meta.nc
# 1054 4903622_meta.nc
# 1055 5906018_meta.nc
# 1056 5904678_meta.nc
# 1057 5905372_meta.nc
# 1058 5906008_meta.nc
# 1059 2902114_meta.nc
# 1060 6903549_meta.nc
# 1061 2901553_meta.nc
# 1062 5904145_meta.nc
# 1063 2902437_meta.nc
# 1064 5906443_meta.nc
# 1065 4903485_meta.nc
# 1066 5904223_meta.nc
# 1067 5901338_meta.nc
# 1068 5904466_meta.nc
# 1069 5906206_meta.nc
# 1070 6901762_meta.nc
# 1071 6901772_meta.nc
# 1072 5906216_meta.nc
# 1073 2902272_meta.nc
# 1074 5904476_meta.nc
# 1075 2903672_meta.nc
# 1076 7900592_meta.nc
# 1077 5905076_meta.nc
# 1078 2900460_meta.nc
# 1079 2902210_meta.nc
# 1080 5906549_meta.nc
# 1081 6900527_meta.nc
# 1082 1901365_meta.nc
# 1083 5906559_meta.nc
# 1084 5901467_meta.nc
# 1085 2902445_meta.nc
# 1086 6902021_meta.nc
# 1087 2902733_meta.nc
# 1088 5904127_meta.nc
# 1089 6904240_meta.nc
# 1090 5903724_meta.nc
# 1091 6901466_meta.nc
# 1092 6901476_meta.nc
# 1093 1902454_meta.nc
# 1094 6902901_meta.nc
# 1095 6903592_meta.nc
# 1096 6902879_meta.nc
# 1097 6903582_meta.nc
# 1098 5903939_meta.nc
# 1099 6902869_meta.nc
# 1100 5902297_meta.nc
# 1101 5903593_meta.nc
# 1102 5902099_meta.nc
# 1103 5906488_meta.nc
# 1104 5906498_meta.nc
# 1105 6901865_meta.nc
# 1106 5906514_meta.nc
# 1107 1901338_meta.nc
# 1108 6903768_meta.nc
# 1109 6901881_meta.nc
# 1110 5901317_meta.nc
# 1111 5902105_meta.nc
# 1112 5906229_meta.nc
# 1113 5906027_meta.nc
# 1114 5904657_meta.nc
# 1115 5901071_meta.nc
# 1116 5903611_meta.nc
# 1117 6903576_meta.nc
# 1118 6900764_meta.nc
# 1119 4902552_meta.nc
# 1120 6902680_meta.nc
# 1121 3902127_meta.nc
# 1122 4900611_meta.nc
# 1123 5904598_meta.nc
# 1124 4902634_meta.nc
# 1125 5905092_meta.nc
# 1126 7900566_meta.nc
# 1127 5905969_meta.nc
# 1128 5904482_meta.nc
# 1129 2902296_meta.nc
# 1130 5905198_meta.nc
# 1131 3902476_meta.nc
# 1132 5905396_meta.nc
# 1133 6900873_meta.nc
# 1134 2902088_meta.nc
# 1135 2900790_meta.nc
# 1136 7900907_meta.nc
# 1137 5904108_meta.nc
# 1138 5901646_meta.nc
# 1139 1901154_meta.nc
# 1140 5906045_meta.nc
# 1141 6901521_meta.nc
# 1142 6902733_meta.nc
# 1143 6901459_meta.nc
# 1144 2903453_meta.nc
# 1145 4902599_meta.nc
# 1146 5905131_meta.nc
# 1147 6901657_meta.nc
# 1148 1901467_meta.nc
# 1149 1900650_meta.nc
# 1150 5906576_meta.nc
# 1151 5901448_meta.nc
# 1152 2903008_meta.nc
# 1153 5906566_meta.nc
# 1154 5901458_meta.nc
# 1155 2903170_meta.nc
# 1156 2900120_meta.nc
# 1157 2901552_meta.nc
# 1158 4902390_meta.nc
# 1159 6903558_meta.nc
# 1160 6900632_meta.nc
# 1161 7900823_meta.nc
# 1162 6903275_meta.nc
# 1163 2902115_meta.nc
# 1164 5906990_meta.nc
# 1165 2900765_meta.nc
# 1166 6903265_meta.nc
# 1167 6900896_meta.nc
# 1168 5906019_meta.nc
# 1169 5905373_meta.nc
# 1170 5904679_meta.nc
# 1171 2902273_meta.nc
# 1172 5906217_meta.nc
# 1173 6901773_meta.nc
# 1174 5904477_meta.nc
# 1175 5904467_meta.nc
# 1176 2902263_meta.nc
# 1177 6901763_meta.nc
# 1178 5906207_meta.nc
# 1179 5901339_meta.nc
# 1180 5903264_meta.nc
# 1181 5906442_meta.nc
# 1182 2902436_meta.nc
# 1183 5903274_meta.nc
# 1184 6903823_meta.nc
# 1185 5906583_meta.nc
# 1186 6903697_meta.nc
# 1187 4901043_meta.nc
# 1188 6902972_meta.nc
# 1189 5904095_meta.nc
# 1190 6902962_meta.nc
# 1191 2902835_meta.nc
# 1192 4902414_meta.nc
# 1193 2902825_meta.nc
# 1194 4903739_meta.nc
# 1195 6900791_meta.nc
# 1196 6902868_meta.nc
# 1197 4903641_meta.nc
# 1198 6902878_meta.nc
# 1199 6902900_meta.nc
# 1200 5906499_meta.nc
# 1201 5906489_meta.nc
# 1202 3900515_meta.nc
# 1203 5903592_meta.nc
# 1204 5901466_meta.nc
# 1205 2902444_meta.nc
# 1206 5906558_meta.nc
# 1207 1901364_meta.nc
# 1208 6900526_meta.nc
# 1209 5906548_meta.nc
# 1210 2902211_meta.nc
# 1211 7900583_meta.nc
# 1212 5905067_meta.nc
# 1213 3900281_meta.nc
# 1214 5905077_meta.nc
# 1215 7900593_meta.nc
# 1216 2902177_meta.nc
# 1217 1902455_meta.nc
# 1218 5904763_meta.nc
# 1219 6901467_meta.nc
# 1220 6904241_meta.nc
# 1221 5904126_meta.nc
# 1222 2902732_meta.nc
# 1223 6902020_meta.nc
# 1224 3902126_meta.nc
# 1225 5904923_meta.nc
# 1226 2902193_meta.nc
# 1227 6901483_meta.nc
# 1228 4902553_meta.nc
# 1229 3900275_meta.nc
# 1230 5905093_meta.nc
# 1231 5904599_meta.nc
# 1232 4900610_meta.nc
# 1233 5901492_meta.nc
# 1234 5906228_meta.nc
# 1235 5905142_meta.nc
# 1236 5901316_meta.nc
# 1237 5906238_meta.nc
# 1238 5906340_meta.nc
# 1239 1901329_meta.nc
# 1240 1901339_meta.nc
# 1241 5906515_meta.nc
# 1242 2900886_meta.nc
# 1243 6903567_meta.nc
# 1244 5905519_meta.nc
# 1245 6903577_meta.nc
# 1246 6902740_meta.nc
# 1247 5906036_meta.nc
# 1248 5906026_meta.nc
# 1249 2900728_meta.nc
# 1250 4902598_meta.nc
# 1251 6903238_meta.nc
# 1252 6901458_meta.nc
# 1253 2902158_meta.nc
# 1254 5906044_meta.nc
# 1255 1901668_meta.nc
# 1256 1901155_meta.nc
# 1257 5901647_meta.nc
# 1258 5901459_meta.nc
# 1259 2903171_meta.nc
# 1260 5906567_meta.nc
# 1261 2903009_meta.nc
# 1262 5901449_meta.nc
# 1263 5906577_meta.nc
# 1264 1900651_meta.nc
# 1265 1901466_meta.nc
# 1266 6903036_meta.nc
# 1267 6901656_meta.nc
# 1268 6904118_meta.nc
# 1269 5905130_meta.nc
# 1270 6901646_meta.nc
# 1271 6903026_meta.nc
# 1272 6901933_meta.nc
# 1273 2902297_meta.nc
# 1274 5905199_meta.nc
# 1275 5904483_meta.nc
# 1276 2900791_meta.nc
# 1277 6900872_meta.nc
# 1278 2902878_meta.nc
# 1279 5905397_meta.nc
# 1280 4901715_meta.nc
# 1281 4901140_meta.nc
# 1282 6902871_meta.nc
# 1283 5904186_meta.nc
# 1284 6902909_meta.nc
# 1285 4903658_meta.nc
# 1286 6900798_meta.nc
# 1287 5906480_meta.nc
# 1288 5906490_meta.nc
# 1289 4903456_meta.nc
# 1290 6904187_meta.nc
# 1291 1901215_meta.nc
# 1292 5906439_meta.nc
# 1293 5906541_meta.nc
# 1294 6901025_meta.nc
# 1295 1901205_meta.nc
# 1296 5903377_meta.nc
# 1297 5906551_meta.nc
# 1298 5905106_meta.nc
# 1299 5906314_meta.nc
# 1300 6903178_meta.nc
# 1301 2902218_meta.nc
# 1302 5906304_meta.nc
# 1303 5904602_meta.nc
# 1304 4901802_meta.nc
# 1305 5906645_meta.nc
# 1306 1902303_meta.nc
# 1307 5904025_meta.nc
# 1308 2900129_meta.nc
# 1309 5903892_meta.nc
# 1310 4900481_meta.nc
# 1311 6903551_meta.nc
# 1312 5904035_meta.nc
# 1313 5904670_meta.nc
# 1314 2902885_meta.nc
# 1315 3901496_meta.nc
# 1316 5901046_meta.nc
# 1317 2900604_meta.nc
# 1318 5904660_meta.nc
# 1319 5906000_meta.nc
# 1320 6903072_meta.nc
# 1321 5905985_meta.nc
# 1322 6901602_meta.nc
# 1323 5905995_meta.nc
# 1324 2901755_meta.nc
# 1325 5906523_meta.nc
# 1326 5906533_meta.nc
# 1327 4900882_meta.nc
# 1328 4902613_meta.nc
# 1329 6902813_meta.nc
# 1330 2900961_meta.nc
# 1331 2903392_meta.nc
# 1332 6902803_meta.nc
# 1333 3902110_meta.nc
# 1334 5901187_meta.nc
# 1335 2900731_meta.nc
# 1336 5903713_meta.nc
# 1337 5901736_meta.nc
# 1338 2903168_meta.nc
# 1339 2903010_meta.nc
# 1340 5901450_meta.nc
# 1341 6900500_meta.nc
# 1342 3901080_meta.nc
# 1343 6904111_meta.nc
# 1344 5905139_meta.nc
# 1345 2900447_meta.nc
# 1346 5906243_meta.nc
# 1347 2903655_meta.nc
# 1348 3900523_meta.nc
# 1349 3900533_meta.nc
# 1350 6903877_meta.nc
# 1351 6903096_meta.nc
# 1352 2903794_meta.nc
# 1353 6903867_meta.nc
# 1354 5905971_meta.nc
# 1355 6903086_meta.nc
# 1356 7901006_meta.nc
# 1357 2900788_meta.nc
# 1358 2902090_meta.nc
# 1359 5904694_meta.nc
# 1360 5904684_meta.nc
# 1361 6901580_meta.nc
# 1362 4900475_meta.nc
# 1363 6902936_meta.nc
# 1364 5904842_meta.nc
# 1365 1902385_meta.nc
# 1366 6902954_meta.nc
# 1367 5904852_meta.nc
# 1368 3901578_meta.nc
# 1369 6902688_meta.nc
# 1370 6903805_meta.nc
# 1371 4900609_meta.nc
# 1372 6901755_meta.nc
# 1373 5905023_meta.nc
# 1374 6902547_meta.nc
# 1375 2902245_meta.nc
# 1376 5906221_meta.nc
# 1377 6903125_meta.nc
# 1378 6901899_meta.nc
# 1379 5903242_meta.nc
# 1380 5906474_meta.nc
# 1381 6902895_meta.nc
# 1382 5901744_meta.nc
# 1383 5904983_meta.nc
# 1384 2900116_meta.nc
# 1385 5904172_meta.nc
# 1386 2901564_meta.nc
# 1387 5902303_meta.nc
# 1388 5901069_meta.nc
# 1389 2902123_meta.nc
# 1390 6901866_meta.nc
# 1391 3902011_meta.nc
# 1392 6903591_meta.nc
# 1393 6900793_meta.nc
# 1394 2900918_meta.nc
# 1395 4903643_meta.nc
# 1396 6903581_meta.nc
# 1397 6900642_meta.nc
# 1398 5904124_meta.nc
# 1399 6901465_meta.nc
# 1400 5904761_meta.nc
# 1401 2902175_meta.nc
# 1402 6902667_meta.nc
# 1403 7900591_meta.nc
# 1404 5905075_meta.nc
# 1405 6900524_meta.nc
# 1406 2902446_meta.nc
# 1407 5901464_meta.nc
# 1408 5906450_meta.nc
# 1409 2902434_meta.nc
# 1410 5906528_meta.nc
# 1411 4903486_meta.nc
# 1412 5904220_meta.nc
# 1413 5906440_meta.nc
# 1414 5906538_meta.nc
# 1415 5906205_meta.nc
# 1416 5904465_meta.nc
# 1417 2903613_meta.nc
# 1418 5904475_meta.nc
# 1419 6901771_meta.nc
# 1420 5906215_meta.nc
# 1421 2902271_meta.nc
# 1422 6903069_meta.nc
# 1423 6903267_meta.nc
# 1424 5905371_meta.nc
# 1425 6904231_meta.nc
# 1426 5903755_meta.nc
# 1427 5903889_meta.nc
# 1428 5904146_meta.nc
# 1429 6900630_meta.nc
# 1430 2903330_meta.nc
# 1431 2901550_meta.nc
# 1432 2902827_meta.nc
# 1433 6902818_meta.nc
# 1434 6902960_meta.nc
# 1435 6902808_meta.nc
# 1436 4901139_meta.nc
# 1437 6902970_meta.nc
# 1438 4901041_meta.nc
# 1439 5906581_meta.nc
# 1440 5905132_meta.nc
# 1441 6903024_meta.nc
# 1442 5906248_meta.nc
# 1443 6901654_meta.nc
# 1444 4900905_meta.nc
# 1445 6903034_meta.nc
# 1446 5906575_meta.nc
# 1447 2903173_meta.nc
# 1448 6902984_meta.nc
# 1449 1901157_meta.nc
# 1450 5904882_meta.nc
# 1451 5901645_meta.nc
# 1452 5903718_meta.nc
# 1453 5901178_meta.nc
# 1454 5903660_meta.nc
# 1455 5906046_meta.nc
# 1456 6901522_meta.nc
# 1457 4903714_meta.nc
# 1458 6903283_meta.nc
# 1459 6900870_meta.nc
# 1460 5905395_meta.nc
# 1461 6902799_meta.nc
# 1462 5904481_meta.nc
# 1463 3902465_meta.nc
# 1464 2902295_meta.nc
# 1465 3901667_meta.nc
# 1466 4903462_meta.nc
# 1467 5905091_meta.nc
# 1468 5906293_meta.nc
# 1469 6903197_meta.nc
# 1470 4902551_meta.nc
# 1471 5904849_meta.nc
# 1472 3902124_meta.nc
# 1473 5904859_meta.nc
# 1474 5902308_meta.nc
# 1475 4902480_meta.nc
# 1476 6902742_meta.nc
# 1477 5903612_meta.nc
# 1478 5906034_meta.nc
# 1479 5901072_meta.nc
# 1480 5900245_meta.nc
# 1481 6903575_meta.nc
# 1482 5904988_meta.nc
# 1483 1901135_meta.nc
# 1484 2900884_meta.nc
# 1485 5904179_meta.nc
# 1486 5906661_meta.nc
# 1487 5906517_meta.nc
# 1488 5903259_meta.nc
# 1489 5906507_meta.nc
# 1490 5902116_meta.nc
# 1491 5906342_meta.nc
# 1492 1902604_meta.nc
# 1493 5905140_meta.nc
# 1494 5901314_meta.nc
# 1495 5906449_meta.nc
# 1496 5906531_meta.nc
# 1497 5906521_meta.nc
# 1498 3902498_meta.nc
# 1499 5905997_meta.nc
# 1500 6901768_meta.nc
# 1501 3902488_meta.nc
# 1502 6903070_meta.nc
# 1503 5906002_meta.nc
# 1504 5904662_meta.nc
# 1505 5905368_meta.nc
# 1506 5901044_meta.nc
# 1507 2900606_meta.nc
# 1508 5904672_meta.nc
# 1509 5901054_meta.nc
# 1510 2900616_meta.nc
# 1511 5905378_meta.nc
# 1512 4900483_meta.nc
# 1513 5903890_meta.nc
# 1514 6903553_meta.nc
# 1515 2901559_meta.nc
# 1516 5904027_meta.nc
# 1517 6900629_meta.nc
# 1518 2903329_meta.nc
# 1519 6902801_meta.nc
# 1520 7900881_meta.nc
# 1521 6902979_meta.nc
# 1522 6902811_meta.nc
# 1523 4903740_meta.nc
# 1524 6902969_meta.nc
# 1525 3901066_meta.nc
# 1526 3901076_meta.nc
# 1527 4900880_meta.nc
# 1528 4903273_meta.nc
# 1529 1901499_meta.nc
# 1530 6903828_meta.nc
# 1531 6904185_meta.nc
# 1532 5906492_meta.nc
# 1533 6903786_meta.nc
# 1534 6903588_meta.nc
# 1535 5904184_meta.nc
# 1536 6902873_meta.nc
# 1537 4901142_meta.nc
# 1538 4901707_meta.nc
# 1539 5906635_meta.nc
# 1540 5904600_meta.nc
# 1541 5904768_meta.nc
# 1542 5903656_meta.nc
# 1543 6901514_meta.nc
# 1544 5906306_meta.nc
# 1545 5905104_meta.nc
# 1546 2903700_meta.nc
# 1547 5906316_meta.nc
# 1548 1901207_meta.nc
# 1549 5906553_meta.nc
# 1550 5905639_meta.nc
# 1551 1901217_meta.nc
# 1552 6901027_meta.nc
# 1553 5903381_meta.nc
# 1554 5905098_meta.nc
# 1555 5904850_meta.nc
# 1556 5901697_meta.nc
# 1557 6902956_meta.nc
# 1558 5902269_meta.nc
# 1559 2902131_meta.nc
# 1560 5902301_meta.nc
# 1561 2900114_meta.nc
# 1562 2901566_meta.nc
# 1563 2902764_meta.nc
# 1564 6902897_meta.nc
# 1565 5904981_meta.nc
# 1566 5906476_meta.nc
# 1567 6903127_meta.nc
# 1568 5906223_meta.nc
# 1569 5903405_meta.nc
# 1570 6901757_meta.nc
# 1571 6902545_meta.nc
# 1572 4900874_meta.nc
# 1573 5906339_meta.nc
# 1574 2903657_meta.nc
# 1575 6904113_meta.nc
# 1576 6900347_meta.nc
# 1577 5901452_meta.nc
# 1578 3901082_meta.nc
# 1579 6903700_meta.nc
# 1580 1900722_meta.nc
# 1581 2903012_meta.nc
# 1582 5901734_meta.nc
# 1583 2900997_meta.nc
# 1584 6902014_meta.nc
# 1585 4901781_meta.nc
# 1586 5903679_meta.nc
# 1587 5903711_meta.nc
# 1588 4901791_meta.nc
# 1589 6903233_meta.nc
# 1590 6902739_meta.nc
# 1591 2900733_meta.nc
# 1592 4900477_meta.nc
# 1593 6902934_meta.nc
# 1594 6900869_meta.nc
# 1595 6901582_meta.nc
# 1596 5904686_meta.nc
# 1597 6901592_meta.nc
# 1598 2902092_meta.nc
# 1599 6903084_meta.nc
# 1600 5905973_meta.nc
# 1601 6903875_meta.nc
# 1602 6903094_meta.nc
# 1603 3900531_meta.nc
# 1604 3900521_meta.nc
# 1605 4902990_meta.nc
# 1606 2900962_meta.nc
# 1607 3900763_meta.nc
# 1608 6902810_meta.nc
# 1609 6902978_meta.nc
# 1610 3902113_meta.nc
# 1611 6902800_meta.nc
# 1612 4900881_meta.nc
# 1613 1901498_meta.nc
# 1614 3901077_meta.nc
# 1615 3901067_meta.nc
# 1616 5905986_meta.nc
# 1617 6903071_meta.nc
# 1618 6901769_meta.nc
# 1619 5905167_meta.nc
# 1620 6901601_meta.nc
# 1621 5905996_meta.nc
# 1622 5906520_meta.nc
# 1623 5906530_meta.nc
# 1624 5906448_meta.nc
# 1625 5904026_meta.nc
# 1626 6900628_meta.nc
# 1627 4901801_meta.nc
# 1628 2901558_meta.nc
# 1629 6903552_meta.nc
# 1630 5904036_meta.nc
# 1631 4900482_meta.nc
# 1632 5903891_meta.nc
# 1633 5905379_meta.nc
# 1634 5904673_meta.nc
# 1635 6901577_meta.nc
# 1636 5906003_meta.nc
# 1637 2900607_meta.nc
# 1638 5901045_meta.nc
# 1639 5905369_meta.nc
# 1640 5904663_meta.nc
# 1641 2902886_meta.nc
# 1642 6901515_meta.nc
# 1643 5904769_meta.nc
# 1644 5904601_meta.nc
# 1645 5906624_meta.nc
# 1646 5906542_meta.nc
# 1647 6901026_meta.nc
# 1648 5906552_meta.nc
# 1649 5905638_meta.nc
# 1650 1901206_meta.nc
# 1651 5906317_meta.nc
# 1652 5905105_meta.nc
# 1653 2903669_meta.nc
# 1654 5906307_meta.nc
# 1655 7900589_meta.nc
# 1656 5906483_meta.nc
# 1657 5906493_meta.nc
# 1658 6904184_meta.nc
# 1659 4901460_meta.nc
# 1660 5904185_meta.nc
# 1661 6902872_meta.nc
# 1662 6903589_meta.nc
# 1663 3902009_meta.nc
# 1664 5904980_meta.nc
# 1665 6902896_meta.nc
# 1666 6902886_meta.nc
# 1667 2900115_meta.nc
# 1668 5902300_meta.nc
# 1669 6903250_meta.nc
# 1670 2902130_meta.nc
# 1671 2902120_meta.nc
# 1672 6903240_meta.nc
# 1673 6902544_meta.nc
# 1674 6901756_meta.nc
# 1675 5905030_meta.nc
# 1676 6903126_meta.nc
# 1677 5906222_meta.nc
# 1678 5906477_meta.nc
# 1679 5905099_meta.nc
# 1680 6902957_meta.nc
# 1681 5904841_meta.nc
# 1682 5901696_meta.nc
# 1683 5904851_meta.nc
# 1684 2902189_meta.nc
# 1685 4902549_meta.nc
# 1686 2902199_meta.nc
# 1687 2902093_meta.nc
# 1688 6901593_meta.nc
# 1689 6901583_meta.nc
# 1690 5904687_meta.nc
# 1691 6900868_meta.nc
# 1692 6902935_meta.nc
# 1693 4900476_meta.nc
# 1694 6901939_meta.nc
# 1695 6903095_meta.nc
# 1696 2903787_meta.nc
# 1697 6903874_meta.nc
# 1698 6903085_meta.nc
# 1699 5905972_meta.nc
# 1700 2903013_meta.nc
# 1701 6903701_meta.nc
# 1702 5901443_meta.nc
# 1703 3901083_meta.nc
# 1704 6903711_meta.nc
# 1705 5901453_meta.nc
# 1706 6900346_meta.nc
# 1707 6904112_meta.nc
# 1708 5906250_meta.nc
# 1709 2903656_meta.nc
# 1710 4901790_meta.nc
# 1711 2900732_meta.nc
# 1712 6902738_meta.nc
# 1713 5903678_meta.nc
# 1714 6903222_meta.nc
# 1715 4901780_meta.nc
# 1716 7900095_meta.nc
# 1717 7900874_meta.nc
# 1718 5901735_meta.nc
# 1719 6902666_meta.nc
# 1720 5904770_meta.nc
# 1721 1902456_meta.nc
# 1722 6901474_meta.nc
# 1723 2902174_meta.nc
# 1724 6901464_meta.nc
# 1725 6903204_meta.nc
# 1726 2903353_meta.nc
# 1727 5904125_meta.nc
# 1728 6900643_meta.nc
# 1729 2902731_meta.nc
# 1730 2902447_meta.nc
# 1731 5901465_meta.nc
# 1732 6900525_meta.nc
# 1733 7900580_meta.nc
# 1734 6904134_meta.nc
# 1735 2901178_meta.nc
# 1736 5905074_meta.nc
# 1737 2903670_meta.nc
# 1738 2902202_meta.nc
# 1739 3900516_meta.nc
# 1740 5902295_meta.nc
# 1741 2900919_meta.nc
# 1742 6903580_meta.nc
# 1743 3900718_meta.nc
# 1744 6900792_meta.nc
# 1745 6903590_meta.nc
# 1746 3902010_meta.nc
# 1747 6902903_meta.nc
# 1748 4901040_meta.nc
# 1749 6902971_meta.nc
# 1750 6902961_meta.nc
# 1751 6902819_meta.nc
# 1752 6900944_meta.nc
# 1753 2902836_meta.nc
# 1754 6900954_meta.nc
# 1755 2902826_meta.nc
# 1756 5906580_meta.nc
# 1757 6903068_meta.nc
# 1758 5904474_meta.nc
# 1759 2902270_meta.nc
# 1760 5906214_meta.nc
# 1761 6901770_meta.nc
# 1762 5902128_meta.nc
# 1763 6901760_meta.nc
# 1764 5906204_meta.nc
# 1765 5904464_meta.nc
# 1766 5906539_meta.nc
# 1767 4903487_meta.nc
# 1768 5906441_meta.nc
# 1769 5906529_meta.nc
# 1770 2902435_meta.nc
# 1771 6900631_meta.nc
# 1772 2901551_meta.nc
# 1773 2900123_meta.nc
# 1774 5904147_meta.nc
# 1775 4902383_meta.nc
# 1776 5903888_meta.nc
# 1777 2902753_meta.nc
# 1778 5903754_meta.nc
# 1779 5905218_meta.nc
# 1780 5905370_meta.nc
# 1781 6903266_meta.nc
# 1782 6902798_meta.nc
# 1783 2900792_meta.nc
# 1784 6900871_meta.nc
# 1785 2900926_meta.nc
# 1786 3900727_meta.nc
# 1787 4903463_meta.nc
# 1788 2902294_meta.nc
# 1789 3902464_meta.nc
# 1790 1901348_meta.nc
# 1791 5906564_meta.nc
# 1792 2903172_meta.nc
# 1793 1900652_meta.nc
# 1794 5906574_meta.nc
# 1795 6903708_meta.nc
# 1796 6903035_meta.nc
# 1797 5906249_meta.nc
# 1798 6903025_meta.nc
# 1799 5905133_meta.nc
# 1800 6901523_meta.nc
# 1801 2903451_meta.nc
# 1802 5903719_meta.nc
# 1803 5901644_meta.nc
# 1804 7900915_meta.nc
# 1805 1901156_meta.nc
# 1806 1901134_meta.nc
# 1807 6903574_meta.nc
# 1808 5904989_meta.nc
# 1809 5904168_meta.nc
# 1810 5906035_meta.nc
# 1811 5903613_meta.nc
# 1812 5901073_meta.nc
# 1813 5904655_meta.nc
# 1814 5902261_meta.nc
# 1815 2902129_meta.nc
# 1816 6902743_meta.nc
# 1817 6903249_meta.nc
# 1818 4902481_meta.nc
# 1819 6901439_meta.nc
# 1820 5901315_meta.nc
# 1821 5905141_meta.nc
# 1822 5906343_meta.nc
# 1823 6901627_meta.nc
# 1824 1902605_meta.nc
# 1825 5902117_meta.nc
# 1826 5903258_meta.nc
# 1827 6990503_meta.nc
# 1828 5906516_meta.nc
# 1829 5903248_meta.nc
# 1830 5905080_meta.nc
# 1831 4902626_meta.nc
# 1832 5901491_meta.nc
# 1833 3902125_meta.nc
# 1834 5904858_meta.nc
# 1835 5904848_meta.nc
# 1836 4900320_meta.nc
# 1837 6901490_meta.nc
# 1838 4902550_meta.nc
#           wmo                                     o2_cal_comment  \
# 0     4901216  DOXY_ADJUSTED corrected based on the WOA 2018 ...
# 1     4901216  Bad data; not adjustable                      ...
# 2     7901019                                                ...
# 3     5904485  DOXY_ADJUSTED corrected using continuous in-ai...
# 4     5904485  none                                          ...
# ...       ...                                                ...
# 2469  4900320  DOXY_ADJUSTED corrected based on the WOA 2018 ...
# 2470  4900320  none                                          ...
# 2471  4900320  Bad data; not adjustable                      ...
# 2472  6901490  Adjusted on CTD at deployment, optode simple c...
# 2473  4902550                                                ...
#
#                                               o2_cal_eq
# 0     PSAT = f(DOXY); PSAT_ADJUSTED = G*PSAT; DOXY_A...
# 1     none                                          ...
# 2                                                   ...
# 3     PSAT = f(DOXY); PSAT_ADJUSTED = G*PSAT; DOXY_A...
# 4     none                                          ...
# ...                                                 ...
# 2469  PSAT = f(DOXY); PSAT_ADJUSTED = G*PSAT; DOXY_A...
# 2470  none                                          ...
# 2471  none                                          ...
# 2472  PPOX_ADJUSTED=OFFSET+(PPOX*SLOPE)*(1+DRIFT/100...
# 2473                                                ...
#
# [2474 rows x 3 columns]

# %%
cal_str_table
# Out:
#           wmo                                     o2_cal_comment  \
# 0     4901216  DOXY_ADJUSTED corrected based on the WOA 2018 ...
# 1     4901216  Bad data; not adjustable                      ...
# 2     7901019                                                ...
# 3     5904485  DOXY_ADJUSTED corrected using continuous in-ai...
# 4     5904485  none                                          ...
# ...       ...                                                ...
# 2469  4900320  DOXY_ADJUSTED corrected based on the WOA 2018 ...
# 2470  4900320  none                                          ...
# 2471  4900320  Bad data; not adjustable                      ...
# 2472  6901490  Adjusted on CTD at deployment, optode simple c...
# 2473  4902550                                                ...
#
#                                               o2_cal_eq
# 0     PSAT = f(DOXY); PSAT_ADJUSTED = G*PSAT; DOXY_A...
# 1     none                                          ...
# 2                                                   ...
# 3     PSAT = f(DOXY); PSAT_ADJUSTED = G*PSAT; DOXY_A...
# 4     none                                          ...
# ...                                                 ...
# 2469  PSAT = f(DOXY); PSAT_ADJUSTED = G*PSAT; DOXY_A...
# 2470  none                                          ...
# 2471  none                                          ...
# 2472  PPOX_ADJUSTED=OFFSET+(PPOX*SLOPE)*(1+DRIFT/100...
# 2473                                                ...
#
# [2474 rows x 3 columns]

# %%
unique_cal_comments = np.unique(cal_str_table.o2_cal_comment)
wmo_comment_data_table = []
for comm in unique_cal_comments:
    n_wmo_for_comment = len(np.unique(cal_str_table.wmo[cal_str_table.o2_cal_comment==comm]))
    # print(n_wmo_for_comment)

    # Create a sublist for each row and append it to wmo_comment_data_table
    row = [comm, n_wmo_for_comment]
    wmo_comment_data_table.append(row)

    # if len(wmo_comment_data_table)==0:
    #     wmo_comment_data_table = [comm, n_wmo_for_comment]
    # else:
    #     wmo_comment_data_table.append([comm, n_wmo_for_comment])

# %%
wmo_comment_data_table
# Out:
# [['                                                                                                                                                                                                                                                                ',
#   381],
#  ['1-point multiplicative correction using WOD at 1008.49 dbar. The quoted error was computed via comparisons with monthly or annual climatology data, interpolated to float location, depth, and season, from WOA09.                                              ',
#   1],
#  ['1-point multiplicative correction using WOD at 1269.58 dbar. The quoted error was computed via comparisons with monthly or annual climatology data, interpolated to float location, depth, and season, from WOA09.                                              ',
#   1],
#  ['1-point multiplicative correction using WOD at 1792.895 dbar. The quoted error was computed via comparisons with monthly or annual climatology data, interpolated to float location, depth, and season, from WOA09.                                             ',
#   1],
#  ['1-point multiplicative correction using WOD at 1794.35 dbar. The quoted error was computed via comparisons with monthly or annual climatology data, interpolated to float location, depth, and season, from WOA09.                                              ',
#   1],
#  ['1-point multiplicative correction using WOD at 1795.3 dbar. The quoted error was computed via comparisons with monthly or annual climatology data, interpolated to float location, depth, and season, from WOA09.                                               ',
#   1],
#  ['1-point multiplicative correction using WOD at 1795.5 dbar. The quoted error was computed via comparisons with monthly or annual climatology data, interpolated to float location, depth, and season, from WOA09.                                               ',
#   1],
#  ['1-point multiplicative correction using WOD at 1795.6 dbar. The quoted error was computed via comparisons with monthly or annual climatology data, interpolated to float location, depth, and season, from WOA09.                                               ',
#   1],
#  ['1-point multiplicative correction using WOD at 1797.7 dbar. The quoted error was computed via comparisons with monthly or annual climatology data, interpolated to float location, depth, and season, from WOA09.                                               ',
#   1],
#  ['1-point multiplicative correction using WOD at 1799.1 dbar. The quoted error was computed via comparisons with monthly or annual climatology data, interpolated to float location, depth, and season, from WOA09.                                               ',
#   1],
#  ['1-point multiplicative correction using WOD at 1799.2 dbar. The quoted error was computed via comparisons with monthly or annual climatology data, interpolated to float location, depth, and season, from WOA09.                                               ',
#   1],
#  ['1-point multiplicative correction using WOD at 1799.4 dbar. The quoted error was computed via comparisons with monthly or annual climatology data, interpolated to float location, depth, and season, from WOA09.                                               ',
#   1],
#  ['1-point multiplicative correction using WOD at 1800 dbar. The quoted error was computed via comparisons with monthly or annual climatology data, interpolated to float location, depth, and season, from WOA09.                                                 ',
#   26],
#  ['Adjust with WOA monthly climatology                                                                                                                                                                                                                             ',
#   1],
#  ['Adjusted PPOX at zero for the minimum and estimate the gain with Annual WOA2018 (OMZ)                                                                                                                                                                           ',
#   3],
#  ['Adjusted PPOX at zero for the minimum and estimate the gain with Monthly WOA2018 (OMZ)                                                                                                                                                                          ',
#   14],
#  ['Adjusted on CTD at deployment, optode simple calibration                                                                                                                                                                                                        ',
#   4],
#  ['Adjusted on WOA annual climatology at surface                                                                                                                                                                                                                   ',
#   1],
#  ['Adjusted on WOA monthly climatology at surface                                                                                                                                                                                                                  ',
#   12],
#  ['Adjusted on WOA with SageO2                                                                                                                                                                                                                                     ',
#   1],
#  ['Adjusted on WOA2018 with SageO2                                                                                                                                                                                                                                 ',
#   1],
#  ['Adjusted on monthly WOA climatology                                                                                                                                                                                                                             ',
#   1],
#  ['Adjusted with SAGEO2 based on WOA climatology                                                                                                                                                                                                                   ',
#   6],
#  ['Adjusted with SAGEO2 on WOA                                                                                                                                                                                                                                     ',
#   3],
#  ['Adjusted with SAGEO2 using continuous in-air measurements                                                                                                                                                                                                       ',
#   1],
#  ['Adjusted with SAGEO2 with in-air measurements (Johnson et al., 2015)                                                                                                                                                                                            ',
#   12],
#  ['Adjusted with SAGEO2, based on WOA climatology                                                                                                                                                                                                                  ',
#   1],
#  ['Adjusted with SageO2, based on WOA climatology                                                                                                                                                                                                                  ',
#   1],
#  ['Adjusted with WOA 2018 monthly climatology , simple calibration                                                                                                                                                                                                 ',
#   1],
#  ['Adjusted with WOA at surface, simple calibration                                                                                                                                                                                                                ',
#   2],
#  ['Adjusted with WOA climatology, optode simple calibration                                                                                                                                                                                                        ',
#   1],
#  ['Adjusted with annual WOA 2018 at surface                                                                                                                                                                                                                        ',
#   1],
#  ['Adjusted with in-air measurements with SAGE-O2                                                                                                                                                                                                                  ',
#   1],
#  ['Adjusted with in-air measurements with SAGEO2                                                                                                                                                                                                                   ',
#   1],
#  ['Adjusted with monthly WOA2018 at surface                                                                                                                                                                                                                        ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from NCEP data - Gain based on comparison between Argo cycle 1 and reference profile ov18_d_101                                                                                                           ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from NCEP data - Gain based on comparison between Argo cycle 1 and reference profile ov18_d_102/                                                                                                          ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from NCEP data - Gain based on comparison between Argo cycle 1 and reference profile ov18_d_49/                                                                                                           ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from NCEP data - Gain based on comparison between Argo cycle 1 and reference profile ov18_d_81/                                                                                                           ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from NCEP data - Gain based on comparison between Argo cycle 11 and reference profile rr17_115/                                                                                                           ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from NCEP data - Gain based on comparison between Argo cycle 3 and reference profile ov18_d_61/                                                                                                           ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from NCEP data - Gain based on comparison between Argo cycle 7 and reference profile rr17_82/                                                                                                             ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from NCEP data - Gain based on comparison between in-air measurements and NCEP, with carry over                                                                                                           ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 1 and reference profile bo16_72/                                                                                            ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 1 and reference profile bo16_78/                                                                                            ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 1 and reference profile cat12_74/                                                                                           ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 1 and reference profile ov18_d_77/                                                                                          ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 1 and reference profile rr15_32                                                                                             ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 1 and reference profile rr17_37                                                                                             ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 107 and reference profile ovid21_25/                                                                                        ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 2 and reference profile ov18_d_105/                                                                                         ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 3 and reference profile cat12_57                                                                                            ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 62   1 and reference profile rr17_1/rr15_20/                                                                                ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 68   69   71   72  148   11   12 and reference profile geov_39/geov_39/geov_39/geov_39/bo16_85/cat12_60/cat12_60/           ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 75 and reference profile geov_17/                                                                                           ',
#   1],
#  ['Adjustment done on PPOX_DOXY;Temporal drift estimated from WOA climatology at surface - Gain based on comparison between Argo cycle 75 and reference profile rr17_106                                                                                           ',
#   1],
#  ['Adjustment via comparison of float surface O2sat to WOA2018 surface O2sat using automatically generated gain from MBARI (jplant@mbari.org). All profiles individually inspected and compared against WOA2018 for accuracy                                       ',
#   16],
#  ['Bad data; not adjustable                                                                                                                                                                                                                                        ',
#   94],
#  ['Bad profile                                                                                                                                                                                                                                                     ',
#   1],
#  ['Biofouling                                                                                                                                                                                                                                                      ',
#   1],
#  ['Biofouling detected                                                                                                                                                                                                                                             ',
#   2],
#  ['Bittig et al. (2021); float in-air data vs. NCEP reanalysis                                                                                                                                                                                                     ',
#   4],
#  ['CTD issues and float issues                                                                                                                                                                                                                                     ',
#   1],
#  ['CTD issues, no adjustment performed                                                                                                                                                                                                                             ',
#   1],
#  ['DOXY_ADJUSTED computed using Stern-Volmer equation with coeffs refit from foil calibration data & WOD data as in Drucker & Riser (2016). The quoted error was computed via comparisons with WOA09 data, interpolated to float location, depth, and season.      ',
#   47],
#  ['DOXY_ADJUSTED corrected based on the WOA 2018 climatology as described in Johnson et al. (2015)                                                                                                                                                                 ',
#   71],
#  ['DOXY_ADJUSTED corrected using continuous in-air measurements as in Johnson et al. (2015)                                                                                                                                                                        ',
#   69],
#  ['DOXY_ADJUSTED is computed from an adjustment of in water PSAT or PPOX float data at surface by comparison to WOA PSAT climatology or WOA PPOX in using PSATWOA and TEMP and PSALfloat at 1 atm, DOXY_ADJUSTED_ERROR is computed from a PPOX_ERROR of 10 mbar    ',
#   7],
#  ['DOXY_ADJUSTED is computed from an adjustment of in water PSAT or PPOX float data at surface by comparison to woaPSAT climatology or WOA PPOX in using woaPSAT and floatTEMP and PSAL at 1 atm, DOXY_ADJUSTED_ERROR is computed from a PPOX_ERROR of 10 mbar     ',
#   73],
#  ['DOXY_ADJUSTED is computed from an adjustment of in water PSAT or PPOX float data at surface by comparison to woaPSAT climatology or WOA PPOX in using woaPSAT and floatTEMP and PSAL at 1 atm, DOXY_ADJUSTED_ERROR is computed from a PPOX_ERROR of 11.3 mbar   ',
#   1],
#  ['DOXY_ADJUSTED is computed from an adjustment of in water PSAT or PPOX float data at surface by comparison to woaPSAT climatology or WOA PPOX in using woaPSAT and floatTEMP and PSAL at 1 atm, DOXY_ADJUSTED_ERROR is computed from a PPOX_ERROR of 13.6 mbar   ',
#   1],
#  ['DOXY_ADJUSTED is computed from an adjustment of in water PSAT or PPOX float data at surface by comparison to woaPSAT climatology or woaPPOX{woaPSAT,floatTEMP,floatPSAL} at 1 atm, DOXY_ADJUSTED_ERROR is computed from a PPOX_ERROR of 10 mbar +1mb/year       ',
#   96],
#  ['DOXY_ADJUSTED is computed from an adjustment of in water PSAT or PPOX float data at surface by comparison to woaPSAT climatology or woaPPOX{woaPSAT,floatTEMP,floatPSAL} at 1 atm, DOXY_ADJUSTED_ERROR is computed from a PPOX_ERROR of 10.0 mbar +1mb/year     ',
#   37],
#  ['DOXY_ADJUSTED is computed from an adjustment of in water PSAT or PPOX float data at surface by comparison to woaPSAT climatology or woaPPOX{woaPSAT,floatTEMP,floatPSAL} at 1 atm, DOXY_ADJUSTED_ERROR is computed from a PPOX_ERROR of 25 mbar +1mb/year       ',
#   1],
#  ['DOXY_ADJUSTED is computed from an adjustment of in water PSAT or PPOX float data at surface by comparison to woaPSAT climatology or woaPPOX{woaPSAT,floatTEMP,floatPSAL} at 1 atm, DOXY_ADJUSTED_ERROR is computed from a PPOX_ERROR of 25.0 mbar +1mb/year     ',
#   1],
#  ['DOXY_ADJUSTED is estimated from an adjustment of in air PPOX float data by comparison to NCEP reanalysis, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 10 mbar                                                                                         ',
#   17],
#  ['DOXY_ADJUSTED is estimated from an adjustment of in air PPOX float data by comparison to NCEP reanalysis, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 10 mbar.                                                                                        ',
#   1],
#  ['DOXY_ADJUSTED is estimated from an adjustment of in air PPOX float data by comparison to NCEP reanalysis, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 3 mbar                                                                                          ',
#   1],
#  ['DOXY_ADJUSTED is estimated from an adjustment of in air PPOX float data by comparison to NCEP reanalysis, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 5 mbar                                                                                          ',
#   1],
#  ['DOXY_ADJUSTED is estimated from an adjustment of in water PPOX float data at surface by comparison to WOA2018 PPOX {woaPSAT, floatTEMP, floatPSAL} at 1 atm; DOXY_ADJUSTED_ERROR recomputed from a PPOX_DOXY_ERROR = 10 mbar increasing by 1 mbar per year      ',
#   96],
#  ['DOXY_ADJUSTED is estimated from an adjustment of in water PSAT or PPOX float data at surface by comparison to WOA PSAT climatology or WOA PPOX in using PSATWOA and TEMP and PSALfloat at 1 atm, DOXY_ADJUSTED_ERROR is estimated from a PPOX_ERROR of 10 mbar. ',
#   34],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment that includes a refined pressure correction coefficient, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 7.2 mbar with an increase of 1mbar/year                                  ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment that includes a refined pressure correction coefficient, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 7.5 mbar with an increase of 1mbar/year                                  ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 10.3 mbar with an increase of 1mbar/year                                                                                         ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 10.7 mbar with an increase of 1mbar/year                                                                                         ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 13.5 mbar with an increase of 1mbar/year                                                                                         ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 3.5 mbar with an increase of 1mbar/year                                                                                          ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 4.2 mbar with an increase of 1mbar/year                                                                                          ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 4.6 mbar with an increase of 1mbar/year                                                                                          ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 5.1 mbar with an increase of 1mbar/year                                                                                          ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 5.2 mbar with an increase of 1mbar/year                                                                                          ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 5.4 mbar with an increase of 1mbar/year                                                                                          ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 7.6 mbar with an increase of 1mbar/year                                                                                          ',
#   2],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 7.7 mbar with an increase of 1mbar/year                                                                                          ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 7.9 mbar with an increase of 1mbar/year                                                                                          ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 8.8 mbar with an increase of 1mbar/year                                                                                          ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 8.9 mbar with an increase of 1mbar/year                                                                                          ',
#   1],
#  ['DOXY_ADJUSTED is estimated from the last valid cycle with DM adjustment, DOXY_ADJUSTED_ERROR is recomputed from a PPOX_ERROR = 9.0 mbar with an increase of 1mbar/year                                                                                          ',
#   1],
#  ['DOXY_QCs are modified during visual check.                                                                                                                                                                                                                      ',
#   33],
#  ['Data are unadjustable owing to dissolved oxygen sensor problem.                                                                                                                                                                                                 ',
#   17],
#  ['G determined by surface measurement comparison to World Ocean Atlas 2009. See Takeshita et al.2013,doi:10.1002/jgrc.20399                                                                                                                                       ',
#   17],
#  ['G determined by surface measurement comparison to World Ocean Atlas 2009.See Takeshita et al.2013,doi:10.1002/jgrc.20399                                                                                                                                        ',
#   2],
#  ['G determined from float  measurements in air. See Johnson et al.,2015,doi:10.1175/JTECH-D-15-0101.1                                                                                                                                                             ',
#   4],
#  ['G determined from float measurements in air. See Johnson et al.,2015,doi:10.1175/JTECH-D-15-0101.1                                                                                                                                                              ',
#   3],
#  ['G obtained from DOXY audit on 2020-11-20                                                                                                                                                                                                                        ',
#   2],
#  ['GAIN determined from WOA2013 O2sat along the five initial float cycles                                                                                                                                                                                          ',
#   35],
#  ['Gain estimated at surface with Monthly WOA2018                                                                                                                                                                                                                  ',
#   2],
#  ['No DOXY data                                                                                                                                                                                                                                                    ',
#   3],
#  ['No QC available for DOXY                                                                                                                                                                                                                                        ',
#   34],
#  ['No adjustment was necessary                                                                                                                                                                                                                                     ',
#   5],
#  ['No significant oxygen drift detected - Calibration error is manufacturer specified accuracy                                                                                                                                                                     ',
#   13],
#  ['Not able to perform a correct adjustment                                                                                                                                                                                                                        ',
#   2],
#  ['Optode issues                                                                                                                                                                                                                                                   ',
#   1],
#  ['Optode out of order                                                                                                                                                                                                                                             ',
#   2],
#  ['Oxygen concentration corrected as a linear function of DOXY; Comparison to the reference profile bo16_74 (isobaric match as in Takeshita et al. (2013)) on cycle 2                                                                                              ',
#   1],
#  ['Oxygen concentration corrected as a linear function of DOXY; Comparison to the reference profile cat12_49 (isobaric match as in Takeshita et al. (2013)) on cycle 1                                                                                             ',
#   1],
#  ['Oxygen concentration corrected as a linear function of DOXY; Comparison to the reference profile cat12_63 (isobaric match as in Takeshita et al. (2013)) on cycle 1                                                                                             ',
#   1],
#  ['Oxygen concentration corrected as a linear function of DOXY; Comparison to the reference profile cat12_78 (isobaric match as in Takeshita et al. (2013)) on cycle 1                                                                                             ',
#   1],
#  ['Oxygen concentration corrected as a linear function of DOXY; Comparison to the reference profile rr15_43 (isobaric match as in Takeshita et al. (2013)) on cycle 104                                                                                            ',
#   1],
#  ['Oxygen gain calculated following Johnson et al. 2015, doi:10.1175/JTECH-D-15-0101.1, using comparison between float and WOA data. Adjustment applied by Christopher Gordon (Fisheries and Oceans Canada, orcid: 0000-0002-1756-422X)                            ',
#   1],
#  ['PPOX adjusted with WOA climatology at surface                                                                                                                                                                                                                   ',
#   1],
#  ['PPOX converted from DOXY, PPOX corrected using in air measurements and SAGEO2, DOXY_ADJUSTED_ERROR recomputed from PPOX_ERROR                                                                                                                                   ',
#   1],
#  ['PSAL_ADJUSTED_QC=4, for the whole life of the float, no DM is performed for DOXY                                                                                                                                                                                ',
#   1],
#  ['Partial pressure corrected as a linear function of PPOX using continuous in-air measurements as in Johnson et al (2015) with sageO2                                                                                                                             ',
#   7],
#  ['Partial pressure corrected as a linear function of PPOX using continuous in-air measurements as in Johnson et al (2015), PPOX converted from DOXY and DOXY_ADJUSTED converted from PPOX_ADJUSTED, ERROR calculated as 2std(A) x 205mbar + 2mbar                 ',
#   5],
#  ['Partial pressure corrected as a linear function of PPOX using in-air measurements as in https://doi.org/10.3389/fmars.2021.683207, PPOX converted from DOXY and DOXY_ADJUSTED converted from PPOX_ADJUSTED, ERROR calculated as 2*std(SLOPE)*205mbar+2mbar      ',
#   12],
#  ['Percent saturation corrected as a linear function of PSAT modified from Takeshita et al (2013); PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED; oxygen corrected as a linear function of DOXY by comparison to a climatology (CARS09)  ',
#   60],
#  ['Percent saturation corrected as a linear function of PSAT modified from Takeshita et al (2013); PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED; oxygen corrected as a linear function of DOXY by comparison to a climatology (CARS09)[G',
#   5],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to a single reference profile (isobaric match as in Takeshita et al. (2013)) on cycle 0; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                          ',
#   13],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to a single reference profile (isobaric match as in Takeshita et al. (2013)) on cycle 1; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                          ',
#   13],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to a single reference profile (isobaric match as in Takeshita et al. (2013)) on cycle 3; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                          ',
#   2],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to the reference profile bo16_15 (isobaric match as in Takeshita et al. (2013)) on cycle 25; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                      ',
#   1],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to the reference profile bo16_48 (isobaric match as in Takeshita et al. (2013)) on cycle 1; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                       ',
#   1],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to the reference profile bo16_62 (isobaric match as in Takeshita et al. (2013)) on cycle 1; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                       ',
#   1],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to the reference profile geov_21 (isobaric match as in Takeshita et al. (2013)) on cycle 3; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                       ',
#   1],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to the reference profile geov_29 (isobaric match as in Takeshita et al. (2013)) on cycle 1; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                       ',
#   1],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to the reference profile rr15_0 (isobaric match as in Takeshita et al. (2013)) on cycle 1; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                        ',
#   1],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to the reference profile rr15_120 (isobaric match as in Takeshita et al. (2013)) on cycle 1; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                      ',
#   3],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to the reference profile rr15_23 (isobaric match as in Takeshita et al. (2013)) on cycle 1; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                       ',
#   1],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to the reference profile rr15_40 (isobaric match as in Takeshita et al. (2013)) on cycle 1; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                       ',
#   1],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to the reference profile rr17_40 (isobaric match as in Takeshita et al. (2013)) on cycle 1; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                       ',
#   1],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to the reference profile rr17_6 (isobaric match as in Takeshita et al. (2013)) on cycle 1; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                        ',
#   1],
#  ['Percent saturation corrected as a linear function of PSAT; Comparison to the reference profile rr17_89 (isobaric match as in Takeshita et al. (2013)) on cycle 1; PSAT converted from DOXY and DOXY_ADJUSTED converted from PSAT_ADJUSTED                       ',
#   1],
#  ['Polynomial calibration coeficients were used. G determined by surface measurement comparison to World Ocean Atlas 2009.See Takeshita et al.2013,doi:10.1002/jgrc.20399                                                                                          ',
#   186],
#  ['Polynomial calibration coeficients were used. G determined by surface measurement comparison to World Ocean Atlas 2009.See Takeshita et al.2013,doi:10.1002/jgrc.20399 PSALproxy used for BGC https://doi.org/10.48670/moi-00052                                ',
#   1],
#  ['Polynomial calibration coeficients were used. G determined from float  measurements in air. See Johnson et al.,2015,doi:10.1175/JTECH-D-15-0101.1                                                                                                               ',
#   86],
#  ['RT adjustment based on extrapolation from previous DMQC adjustment; DOXY adjusted by gain-only factor on DOXY                                                                                                                                                   ',
#   17],
#  ['RT adjustment by comparison of float surface O2sat to WOA13 surface O2sat; DOXY adjusted by gain-only factor on DOXY                                                                                                                                            ',
#   10],
#  ['RT adjustment by comparison of float surface O2sat to WOA18 surface O2sat; DOXY adjusted by gain-only factor on DOXY                                                                                                                                            ',
#   17],
#  ['RT adjustment by comparison of float surface O2sat to WOA2018 surface O2sat using automatically generated gain from MBARI (jplant@mbari.org)                                                                                                                    ',
#   24],
#  ['SVU Foil calibration coeficients were used. G determined by surface measurement comparison to World Ocean Atlas 2009.See Takeshita et al.2013,doi:10.1002/jgrc.20399                                                                                            ',
#   44],
#  ['SVU Foil calibration coeficients were used. G determined from float  measurements in air. See Johnson et al.,2015,doi:10.1175/JTECH-D-15-0101.1                                                                                                                 ',
#   253],
#  ['Sensor Issue                                                                                                                                                                                                                                                    ',
#   3],
#  ['Sensor Issues                                                                                                                                                                                                                                                   ',
#   1],
#  ['Sensor issue                                                                                                                                                                                                                                                    ',
#   6],
#  ['Sensor issue, not able to adjust                                                                                                                                                                                                                                ',
#   1],
#  ['Sensor issues                                                                                                                                                                                                                                                   ',
#   1],
#  ['Sensors issues                                                                                                                                                                                                                                                  ',
#   1],
#  ['Single point, no adjustment                                                                                                                                                                                                                                     ',
#   1],
#  ['Takeshita and all, 2013 based on MONTHLY WOA climatology, optode simple calibration                                                                                                                                                                             ',
#   2],
#  ['Takeshita and all, 2013 based on YEARLY WOA climatology, optode simple calibration                                                                                                                                                                              ',
#   1],
#  ['Unable to estimate correctly a gain on the few good profiles available (sensor issue)                                                                                                                                                                           ',
#   1],
#  ['adjusted with median of the annual WOA climato at surface                                                                                                                                                                                                       ',
#   2],
#  ['adjusted with median of the monthly WOA climato at surface                                                                                                                                                                                                      ',
#   5],
#  ['adjusted with median of the monthly WOA climato at surface, old APEX converted 3.1                                                                                                                                                                              ',
#   3],
#  ['after Bittig et al. (2018) eq. 21, float in-air data vs. ERA5 reanalysis                                                                                                                                                                                        ',
#   1],
#  ['after Bittig et al. (2018) eq. 21, float in-air data vs. NCEP reanalysis                                                                                                                                                                                        ',
#   4],
#  ['after Bittig et al. (2018) eq. 23, float in-air data vs. NCEP reanalysis                                                                                                                                                                                        ',
#   4],
#  ['after Bittiing et al (2018) eq 23 no in-air data-compared to WOA                                                                                                                                                                                                ',
#   1],
#  ['after Bittin et al (2018) no in air data, compared to WOA                                                                                                                                                                                                       ',
#   1],
#  ['after Bitting at al (2018) eq. 23, no in air data, WOD used                                                                                                                                                                                                     ',
#   1],
#  ['after Bitting at all (2018) eq.32, no in air data, WOD used                                                                                                                                                                                                     ',
#   1],
#  ['after Bitting et al (2018) eq 23 No in air data available, compared with WOA                                                                                                                                                                                    ',
#   1],
#  ['after Bitting et al (2018) eq 23, float with no in air data, compared to WOA                                                                                                                                                                                    ',
#   1],
#  ['after Bitting et al. (2018) eq 23 float with no in air data compared to WOA                                                                                                                                                                                     ',
#   2],
#  ['after Bitting et al. (2018) eq 23 no in air data, compared to WOA                                                                                                                                                                                               ',
#   1],
#  ['after Bitting et al. (2018) eq 23, no in air data available vs WOA                                                                                                                                                                                              ',
#   1],
#  ['after Bitting et al. (2018) float with no in air data vs WOD data                                                                                                                                                                                               ',
#   1],
#  ['after Bitting et al.(2018) eq 23 float with no in air compared with WOD                                                                                                                                                                                         ',
#   1],
#  ['after bitting et al. (2018) eq 23 no in air data compared to WOD                                                                                                                                                                                                ',
#   1],
#  ['bad data                                                                                                                                                                                                                                                        ',
#   1],
#  ['by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 21 slope on PPOX_DOXY with linear time trend in slope; Using in-air obs; No time response correction done; error gives 1 sigma                                                       ',
#   1],
#  ['by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 21 slope on PPOX_DOXY; Using in-air obs; No time response correction done; error gives 1 sigma                                                                                       ',
#   5],
#  ['by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 23 T-dependent slope on PPOX_DOXY with linear time trend in slope; Using in-air obs; No time response correction done; error gives 1 sigma                                           ',
#   7],
#  ['by Henry Bittig; ORCID 0000-0002-8621-3095; after Bittig et al. (2018) eq. 23 T-dependent slope on PPOX_DOXY; Using in-air obs; No time response correction done; error gives 1 sigma                                                                           ',
#   5],
#  ['by Henry Bittig; ORCID iD 0000-0002-8621-3095; Johnson et al. (2015) average gain (unfiltered) on PPOX_DOXY; Using in-air obs; time response correction (Bittig et al., 2018) with lL scale factor 0.60; error gives 95 % CI                                    ',
#   1],
#  ['by Henry Bittig; ORCID iD 0000-0002-8621-3095; Johnson et al. (2015) average gain (unfiltered) on PPOX_DOXY; Using in-air obs; time response correction (Bittig et al., 2018) with lL scale factor 0.65; error gives 95 % CI                                    ',
#   1],
#  ['by Henry Bittig; ORCID iD 0000-0002-8621-3095; Johnson et al. (2015) average gain (unfiltered) on PPOX_DOXY; Using in-air obs; time response correction (Bittig et al., 2018) with lL scale factor 0.70; error gives 95 % CI                                    ',
#   3],
#  ['by Henry Bittig; ORCID iD 0000-0002-8621-3095; Johnson et al. (2015) average gain (unfiltered) on PPOX_DOXY; Using in-air obs; time response correction (Bittig et al., 2018) with lL scale factor 0.75; error gives 95 % CI                                    ',
#   6],
#  ['n/a                                                                                                                                                                                                                                                             ',
#   7],
#  ['no adjustment is performed because of issues in CTD                                                                                                                                                                                                             ',
#   51],
#  ['none                                                                                                                                                                                                                                                            ',
#   72],
#  ['not applicable                                                                                                                                                                                                                                                  ',
#   13],
#  ['optode multi calibration, adjusted with median of the annual WOA climato at surface                                                                                                                                                                             ',
#   36],
#  ['optode multi calibration, adjusted with median of the monthly WOA climato at surface                                                                                                                                                                            ',
#   26],
#  ['optode multi calibration, adjusted with median of the monthly WOA climato at surface + drift ajustement                                                                                                                                                         ',
#   3],
#  ['optode multi calibration, adjusted with median of the yearly WOA climato at surface + drift ajustement                                                                                                                                                          ',
#   1],
#  ['optode simple calibration, adjusted with CTD at deployment                                                                                                                                                                                                      ',
#   1]]

# %%
df = pd.DataFrame(wmo_comment_data_table)
csv_file=  'wmo_comment_data_table.csv'

# %%
# Write the list to the CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(wmo_comment_data_table)

# %%
o2_offset_data_table = []
len(o2_offset_data_table)
# Out:
# 0

# %%
o2_cal_full = []
o2_eq_full = []

for idx, o2_ind in enumerate(o2_ind_all):
    if ~np.isnan(o2_ind):
        o2_cal_full.append(sprof_n.SCIENTIFIC_CALIB_COMMENT.values[idx,-1,np.int32(o2_ind)])
        # pd.concat([o2_cal_full]+ sprof_n.SCIENTIFIC_CALIB_COMMENT.values[idx,-1,np.int32(o2_ind)], ignore_index=True)
        o2_eq_full.append(sprof_n.SCIENTIFIC_CALIB_EQUATION.values[idx,-1,np.int32(o2_ind)])

    # print(o2_cal_full)
data_comment_eq = pd.DataFrame({'o2_cal_full': o2_cal_full, 'o2_eq_full': o2_eq_full})
unique_pairs = data_comment_eq.drop_duplicates()

print(unique_pairs)
# Out:
#                                          o2_cal_full  \
# 0  b'DOXY_ADJUSTED is computed from an adjustment...
#
#                                           o2_eq_full
# 0  b'PPOX_DOXY=f(DOXY), PPOX_DOXY_ADJUSTED=(SLOPE...

# %%
len(o2_cal_full)
# Out:
# 30

# %%
tt = sprof_n.SCIENTIFIC_CALIB_COMMENT.values[1,-1,np.int32(o2_ind)]

print(tt)
# Out:
# b'DOXY_ADJUSTED is computed from an adjustment of in water PSAT or PPOX float data at surface by comparison to woaPSAT climatology or woaPPOX{woaPSAT,floatTEMP,floatPSAL} at 1 atm, DOXY_ADJUSTED_ERROR is computed from a PPOX_ERROR of 10.0 mbar +1mb/year     '

# %%
p = 1
cal_str = sprof_n.STATION_PARAMETERS.values.astype(str)[p]
print(cal_str)
# Out:
# ['PRES                                                            '
#  'TEMP                                                            '
#  'PSAL                                                            '
#  'DOXY                                                            '
#  'DOWN_IRRADIANCE380                                              '
#  'DOWN_IRRADIANCE412                                              '
#  'DOWN_IRRADIANCE490                                              '
#  'DOWNWELLING_PAR                                                 '
#  'CHLA                                                            '
#  'BBP700                                                          '
#  'CDOM                                                            '
#  'PH_IN_SITU_TOTAL                                                ']

# %%
o2_cal_full = sprof_n.SCIENTIFIC_CALIB_COMMENT.values[:,-1,o2_ind]
o2_eq_full = sprof_n.SCIENTIFIC_CALIB_EQUATION.values[:,-1,o2_ind]

data_comment_eq = pd.DataFrame({'o2_cal_full': o2_cal_full, 'o2_eq_full': o2_eq_full})

# Drop duplicate rows to get unique pairs
unique_pairs = data_comment_eq.drop_duplicates()

print(unique_pairs.o2_cal_full[0])
# Out:
# b'DOXY_ADJUSTED corrected using continuous in-air measurements as in Johnson et al. (2015)                                                                                                                                                                        '

# %%
# o2_eq = sprof_n.SCIENTIFIC_CALIB_EQUATION.values[0,-1,o2_ind].decode("utf-8")
# 
o2_eq = np.unique(sprof_n.SCIENTIFIC_CALIB_EQUATION.values[:,-1,o2_ind])
print(o2_eq)
print(o2_cal)
# Out:
# [b'PSAT = f(DOXY); PSAT_ADJUSTED = G*PSAT; DOXY_ADJUSTED = f(PSAT_ADJUSTED)                                                                                                                                                                                        '
#  b'none                                                                                                                                                                                                                                                            ']
# [b'Bad data; not adjustable                                                                                                                                                                                                                                        '
#  b'DOXY_ADJUSTED corrected using continuous in-air measurements as in Johnson et al. (2015)                                                                                                                                                                        '
#  b'none                                                                                                                                                                                                                                                            ']

# %%
# cal_str_table = pd.DataFrame(columns=['wmo','o2_cal_comment'])

#also load meta file  for same float
file_n = argo_path + file
meta_n = xr.open_dataset(argo_path + file)
# meta_n
parameters_n = meta_n.PARAMETER.values
# print(parameters_n)

contains_doxy = any(parameter.decode('utf-8').strip() == 'DOXY' for parameter in parameters_n)
if contains_doxy is False:
    # continue
    print('no doxy')

# not sure if i need this, but loading the Sprof file as well

wmo_n = int((re.search(r'\d+', file)).group())

sprof_n = xr.open_dataset(argo_path + str(wmo_n) + '_Sprof.nc')

# gets order of sensors to extract calibration comments
cal_str = sprof_n.STATION_PARAMETERS.values.astype(str)[0]
# print(cal_str)

for i, param in enumerate(cal_str):
    if 'DOXY' in param:
        o2_ind = i
        break
# print(i)
o2_cal_full = sprof_n.SCIENTIFIC_CALIB_COMMENT.values[:,-1,o2_ind]
o2_cal_unique = np.unique(o2_cal_full)

# print(o2_cal_unique)
# might have multiple unique comments, so save out each one:
for i in range(len(o2_cal_unique)):
    o2_cal_i = o2_cal_unique[i].decode("utf-8")
    print(o2_cal_i)
    # save with wmo only for now
    new_data_cal_info = pd.DataFrame({'wmo': [wmo_n],
                                      'o2_cal_comment': [o2_cal_i]})
    # Append the new_data_cal_info DataFrame to cal_str_table
    cal_str_table = cal_str_table.append(new_data_cal_info, ignore_index=True)
# Out:
# /var/folders/7r/4f_w_nb56llcwh96t_pjq_qh0000gn/T/ipykernel_86162/3566382346.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cal_str_table = cal_str_table.append(new_data_cal_info, ignore_index=True)

# %%
cal_str.
# Out:
# array(['PRES                                                            ',
#        'TEMP                                                            ',
#        'PSAL                                                            ',
#        'DOXY                                                            '],
#       dtype='<U64')

# %%
# Out:
# [b'                                                                                                                                                                                                                                                                ']

# %%
parameters_n = meta_n.PARAMETER.values
print(parameters_n)

contains_doxy = any(parameter.decode('utf-8').strip() == 'DOXY' for parameter in parameters_n)
contains_doxy
# Out:
# [b'PRES                                                            '
#  b'TEMP                                                            '
#  b'PSAL                                                            '
#  b'C1PHASE_DOXY                                                    '
#  b'C2PHASE_DOXY                                                    '
#  b'DOXY                                                            '
#  b'TEMP_DOXY                                                       '
#  b'PPOX_DOXY                                                       ']
# True
